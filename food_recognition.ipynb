# %% [markdown]
# <a href="https://colab.research.google.com/github/yeansreymom25-eng/food-recognition-nutrition/blob/main/food_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Project Information
#
# Food Recognition and Nutritional Estimation Using Deep Learning
#
# Student: Yean Sreymom
#
# Framework: PyTorch
# Model: MobileNetV2 CNN with Transfer Learning
#
# Food Classes: 20
#
# Categories: 5

# %% [markdown]
# # 2. Mount Google Drive
#
# This section connects Google Colab to Google Drive so the notebook can access the dataset and save project files.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 3. Dataset Collection
#
# This section collects food images from public datasets such as Food-101 and Fruits-360 and saves the selected images into Google Drive.

# %%
import os
import requests

# Fruits-360 Almond folder
url = "https://api.github.com/repos/fruits-360/fruits-360-100x100/contents/Training/Almonds%201"

# Your Google Drive almond folder
save_folder = "/content/drive/MyDrive/Food_Recognition_Project/dataset/almond"

os.makedirs(save_folder, exist_ok=True)

files = requests.get(url).json()

images = [
    file for file in files
    if file["name"].lower().endswith((".jpg", ".jpeg", ".png"))
]

# Use only 150 images
images = images[:150]

for number, image in enumerate(images, start=1):
    image_data = requests.get(image["download_url"]).content

    save_path = os.path.join(save_folder, image["name"])

    with open(save_path, "wb") as f:
        f.write(image_data)

    print(f"{number}/{len(images)} downloaded")

print("Almond finished!")
# Out:
# 1/150 downloaded
# 2/150 downloaded
# 3/150 downloaded
# 4/150 downloaded
# 5/150 downloaded
# 6/150 downloaded
# 7/150 downloaded
# 8/150 downloaded
# 9/150 downloaded
# 10/150 downloaded
# 11/150 downloaded
# 12/150 downloaded
# 13/150 downloaded
# 14/150 downloaded
# 15/150 downloaded
# 16/150 downloaded
# 17/150 downloaded
# 18/150 downloaded
# 19/150 downloaded
# 20/150 downloaded
# 21/150 downloaded
# 22/150 downloaded
# 23/150 downloaded
# 24/150 downloaded
# 25/150 downloaded
# 26/150 downloaded
# 27/150 downloaded
# 28/150 downloaded
# 29/150 downloaded
# 30/150 downloaded
# 31/150 downloaded
# 32/150 downloaded
# 33/150 downloaded
# 34/150 downloaded
# 35/150 downloaded
# 36/150 downloaded
# 37/150 downloaded
# 38/150 downloaded
# 39/150 downloaded
# 40/150 downloaded
# 41/150 downloaded
# 42/150 downloaded
# 43/150 downloaded
# 44/150 downloaded
# 45/150 downloaded
# 46/150 downloaded
# 47/150 downloaded
# 48/150 downloaded
# 49/150 downloaded
# 50/150 downloaded
# ...

# %%
import os
import requests

# Fruits-360 Apple folder
url = "https://api.github.com/repos/fruits-360/fruits-360-100x100/contents/Training/Apple%20Red%201"

# Save into your Google Drive apple folder
save_folder = "/content/drive/MyDrive/Food_Recognition_Project/dataset/apple"

os.makedirs(save_folder, exist_ok=True)

files = requests.get(url).json()

images = [
    file for file in files
    if file["name"].lower().endswith((".jpg", ".jpeg", ".png"))
]

# Take only 150 images
images = images[:150]

for number, image in enumerate(images, start=1):
    image_data = requests.get(image["download_url"]).content

    save_path = os.path.join(save_folder, image["name"])

    with open(save_path, "wb") as f:
        f.write(image_data)

    print(f"{number}/{len(images)} downloaded")

print("Apple finished!")
# Out:
# 1/150 downloaded
# 2/150 downloaded
# 3/150 downloaded
# 4/150 downloaded
# 5/150 downloaded
# 6/150 downloaded
# 7/150 downloaded
# 8/150 downloaded
# 9/150 downloaded
# 10/150 downloaded
# 11/150 downloaded
# 12/150 downloaded
# 13/150 downloaded
# 14/150 downloaded
# 15/150 downloaded
# 16/150 downloaded
# 17/150 downloaded
# 18/150 downloaded
# 19/150 downloaded
# 20/150 downloaded
# 21/150 downloaded
# 22/150 downloaded
# 23/150 downloaded
# 24/150 downloaded
# 25/150 downloaded
# 26/150 downloaded
# 27/150 downloaded
# 28/150 downloaded
# 29/150 downloaded
# 30/150 downloaded
# 31/150 downloaded
# 32/150 downloaded
# 33/150 downloaded
# 34/150 downloaded
# 35/150 downloaded
# 36/150 downloaded
# 37/150 downloaded
# 38/150 downloaded
# 39/150 downloaded
# 40/150 downloaded
# 41/150 downloaded
# 42/150 downloaded
# 43/150 downloaded
# 44/150 downloaded
# 45/150 downloaded
# 46/150 downloaded
# 47/150 downloaded
# 48/150 downloaded
# 49/150 downloaded
# 50/150 downloaded
# ...

# %%
import os
import requests

# Correct Fruits-360 Banana folder
url = "https://api.github.com/repos/fruits-360/fruits-360-100x100/contents/Training/Banana%201"

# Your Google Drive banana folder
save_folder = "/content/drive/MyDrive/Food_Recognition_Project/dataset/banana"

os.makedirs(save_folder, exist_ok=True)

response = requests.get(url)
files = response.json()

images = [
    file for file in files
    if file["name"].lower().endswith((".jpg", ".jpeg", ".png"))
]

images = images[:150]

for number, image in enumerate(images, start=1):
    image_data = requests.get(image["download_url"]).content

    save_path = os.path.join(save_folder, image["name"])

    with open(save_path, "wb") as f:
        f.write(image_data)

    print(f"{number}/{len(images)} downloaded")

print("Banana finished!")
# Out:
# 1/150 downloaded
# 2/150 downloaded
# 3/150 downloaded
# 4/150 downloaded
# 5/150 downloaded
# 6/150 downloaded
# 7/150 downloaded
# 8/150 downloaded
# 9/150 downloaded
# 10/150 downloaded
# 11/150 downloaded
# 12/150 downloaded
# 13/150 downloaded
# 14/150 downloaded
# 15/150 downloaded
# 16/150 downloaded
# 17/150 downloaded
# 18/150 downloaded
# 19/150 downloaded
# 20/150 downloaded
# 21/150 downloaded
# 22/150 downloaded
# 23/150 downloaded
# 24/150 downloaded
# 25/150 downloaded
# 26/150 downloaded
# 27/150 downloaded
# 28/150 downloaded
# 29/150 downloaded
# 30/150 downloaded
# 31/150 downloaded
# 32/150 downloaded
# 33/150 downloaded
# 34/150 downloaded
# 35/150 downloaded
# 36/150 downloaded
# 37/150 downloaded
# 38/150 downloaded
# 39/150 downloaded
# 40/150 downloaded
# 41/150 downloaded
# 42/150 downloaded
# 43/150 downloaded
# 44/150 downloaded
# 45/150 downloaded
# 46/150 downloaded
# 47/150 downloaded
# 48/150 downloaded
# 49/150 downloaded
# 50/150 downloaded
# ...

# %%
import os
import requests

# Where to save Orange images
save_folder = "/content/gdrive/MyDrive/Food_Recognition_Project/dataset/orange"
os.makedirs(save_folder, exist_ok=True)

# Get all Fruits-360 training folders
url = "https://api.github.com/repos/fruits-360/fruits-360-100x100/contents/Training"
folders = requests.get(url).json()

# Find an Orange folder automatically
orange_folder = None

for item in folders:
    if item["type"] == "dir" and item["name"].lower().startswith("orange"):
        orange_folder = item
        break

print("Using folder:", orange_folder["name"])

# Get images
files = requests.get(orange_folder["url"]).json()

images = [
    f for f in files
    if f["name"].lower().endswith((".jpg", ".jpeg", ".png"))
]

images = images[:150]

for number, image in enumerate(images, start=1):
    image_data = requests.get(image["download_url"]).content

    with open(os.path.join(save_folder, image["name"]), "wb") as f:
        f.write(image_data)

    print(f"{number}/{len(images)} downloaded")

print("Orange finished!")
print("Images saved:", len(os.listdir(save_folder)))
# Out:
# Using folder: Orange 1
# 1/150 downloaded
# 2/150 downloaded
# 3/150 downloaded
# 4/150 downloaded
# 5/150 downloaded
# 6/150 downloaded
# 7/150 downloaded
# 8/150 downloaded
# 9/150 downloaded
# 10/150 downloaded
# 11/150 downloaded
# 12/150 downloaded
# 13/150 downloaded
# 14/150 downloaded
# 15/150 downloaded
# 16/150 downloaded
# 17/150 downloaded
# 18/150 downloaded
# 19/150 downloaded
# 20/150 downloaded
# 21/150 downloaded
# 22/150 downloaded
# 23/150 downloaded
# 24/150 downloaded
# 25/150 downloaded
# 26/150 downloaded
# 27/150 downloaded
# 28/150 downloaded
# 29/150 downloaded
# 30/150 downloaded
# 31/150 downloaded
# 32/150 downloaded
# 33/150 downloaded
# 34/150 downloaded
# 35/150 downloaded
# 36/150 downloaded
# 37/150 downloaded
# 38/150 downloaded
# 39/150 downloaded
# 40/150 downloaded
# 41/150 downloaded
# 42/150 downloaded
# 43/150 downloaded
# 44/150 downloaded
# 45/150 downloaded
# 46/150 downloaded
# 47/150 downloaded
# 48/150 downloaded
# 49/150 downloaded
# ...

# %%
import os
import requests

# Save folder in your real Google Drive
save_folder = "/content/gdrive/MyDrive/Food_Recognition_Project/dataset/strawberry"
os.makedirs(save_folder, exist_ok=True)

# Fruits-360 Training folder
url = "https://api.github.com/repos/fruits-360/fruits-360-100x100/contents/Training"
folders = requests.get(url).json()

# Find Strawberry folder automatically
strawberry_folder = None

for item in folders:
    if item["type"] == "dir" and item["name"].lower().startswith("strawberry"):
        strawberry_folder = item
        break

print("Using folder:", strawberry_folder["name"])

# Get images
files = requests.get(strawberry_folder["url"]).json()

images = [
    f for f in files
    if f["name"].lower().endswith((".jpg", ".jpeg", ".png"))
]

images = images[:150]

for number, image in enumerate(images, start=1):
    image_data = requests.get(image["download_url"]).content

    with open(os.path.join(save_folder, image["name"]), "wb") as f:
        f.write(image_data)

    print(f"{number}/{len(images)} downloaded")

print("Strawberry finished!")
print("Images saved:", len(os.listdir(save_folder)))
# Out:
# Using folder: Strawberry 1
# 1/150 downloaded
# 2/150 downloaded
# 3/150 downloaded
# 4/150 downloaded
# 5/150 downloaded
# 6/150 downloaded
# 7/150 downloaded
# 8/150 downloaded
# 9/150 downloaded
# 10/150 downloaded
# 11/150 downloaded
# 12/150 downloaded
# 13/150 downloaded
# 14/150 downloaded
# 15/150 downloaded
# 16/150 downloaded
# 17/150 downloaded
# 18/150 downloaded
# 19/150 downloaded
# 20/150 downloaded
# 21/150 downloaded
# 22/150 downloaded
# 23/150 downloaded
# 24/150 downloaded
# 25/150 downloaded
# 26/150 downloaded
# 27/150 downloaded
# 28/150 downloaded
# 29/150 downloaded
# 30/150 downloaded
# 31/150 downloaded
# 32/150 downloaded
# 33/150 downloaded
# 34/150 downloaded
# 35/150 downloaded
# 36/150 downloaded
# 37/150 downloaded
# 38/150 downloaded
# 39/150 downloaded
# 40/150 downloaded
# 41/150 downloaded
# 42/150 downloaded
# 43/150 downloaded
# 44/150 downloaded
# 45/150 downloaded
# 46/150 downloaded
# 47/150 downloaded
# 48/150 downloaded
# 49/150 downloaded
# ...

# %%
import os
import requests

# Save folder in your real Google Drive
save_folder = "/content/gdrive/MyDrive/Food_Recognition_Project/dataset/carrot"
os.makedirs(save_folder, exist_ok=True)

# Fruits-360 Training folder
url = "https://api.github.com/repos/fruits-360/fruits-360-100x100/contents/Training"
folders = requests.get(url).json()

# Find Carrot folder automatically
carrot_folder = None

for item in folders:
    if item["type"] == "dir" and item["name"].lower().startswith("carrot"):
        carrot_folder = item
        break

if carrot_folder is None:
    print("Carrot folder not found")
else:
    print("Using folder:", carrot_folder["name"])

    files = requests.get(carrot_folder["url"]).json()

    images = [
        f for f in files
        if f["name"].lower().endswith((".jpg", ".jpeg", ".png"))
    ]

    images = images[:150]

    for number, image in enumerate(images, start=1):
        image_data = requests.get(image["download_url"]).content

        with open(os.path.join(save_folder, image["name"]), "wb") as f:
            f.write(image_data)

        print(f"{number}/{len(images)} downloaded")

    print("Carrot finished!")
    print("Images saved:", len(os.listdir(save_folder)))
# Out:
# Using folder: Carrot 1
# 1/150 downloaded
# 2/150 downloaded
# 3/150 downloaded
# 4/150 downloaded
# 5/150 downloaded
# 6/150 downloaded
# 7/150 downloaded
# 8/150 downloaded
# 9/150 downloaded
# 10/150 downloaded
# 11/150 downloaded
# 12/150 downloaded
# 13/150 downloaded
# 14/150 downloaded
# 15/150 downloaded
# 16/150 downloaded
# 17/150 downloaded
# 18/150 downloaded
# 19/150 downloaded
# 20/150 downloaded
# 21/150 downloaded
# 22/150 downloaded
# 23/150 downloaded
# 24/150 downloaded
# 25/150 downloaded
# 26/150 downloaded
# 27/150 downloaded
# 28/150 downloaded
# 29/150 downloaded
# 30/150 downloaded
# 31/150 downloaded
# 32/150 downloaded
# 33/150 downloaded
# 34/150 downloaded
# 35/150 downloaded
# 36/150 downloaded
# 37/150 downloaded
# 38/150 downloaded
# 39/150 downloaded
# 40/150 downloaded
# 41/150 downloaded
# 42/150 downloaded
# 43/150 downloaded
# 44/150 downloaded
# 45/150 downloaded
# 46/150 downloaded
# 47/150 downloaded
# 48/150 downloaded
# 49/150 downloaded
# ...

# %%
import os
import requests

save_folder = "/content/gdrive/MyDrive/Food_Recognition_Project/dataset/tomato"
os.makedirs(save_folder, exist_ok=True)

url = "https://api.github.com/repos/fruits-360/fruits-360-100x100/contents/Training"
folders = requests.get(url).json()

tomato_folder = None

for item in folders:
    if item["type"] == "dir" and item["name"].lower().startswith("tomato"):
        tomato_folder = item
        break

if tomato_folder is None:
    print("Tomato folder not found")
else:
    print("Using folder:", tomato_folder["name"])

    files = requests.get(tomato_folder["url"]).json()

    images = [
        f for f in files
        if f["name"].lower().endswith((".jpg", ".jpeg", ".png"))
    ]

    images = images[:150]

    for number, image in enumerate(images, start=1):
        image_data = requests.get(image["download_url"]).content

        with open(os.path.join(save_folder, image["name"]), "wb") as f:
            f.write(image_data)

        print(f"{number}/{len(images)} downloaded")

    print("Tomato finished!")
    print("Images saved:", len(os.listdir(save_folder)))
# Out:
# Using folder: Tomato 1
# 1/150 downloaded
# 2/150 downloaded
# 3/150 downloaded
# 4/150 downloaded
# 5/150 downloaded
# 6/150 downloaded
# 7/150 downloaded
# 8/150 downloaded
# 9/150 downloaded
# 10/150 downloaded
# 11/150 downloaded
# 12/150 downloaded
# 13/150 downloaded
# 14/150 downloaded
# 15/150 downloaded
# 16/150 downloaded
# 17/150 downloaded
# 18/150 downloaded
# 19/150 downloaded
# 20/150 downloaded
# 21/150 downloaded
# 22/150 downloaded
# 23/150 downloaded
# 24/150 downloaded
# 25/150 downloaded
# 26/150 downloaded
# 27/150 downloaded
# 28/150 downloaded
# 29/150 downloaded
# 30/150 downloaded
# 31/150 downloaded
# 32/150 downloaded
# 33/150 downloaded
# 34/150 downloaded
# 35/150 downloaded
# 36/150 downloaded
# 37/150 downloaded
# 38/150 downloaded
# 39/150 downloaded
# 40/150 downloaded
# 41/150 downloaded
# 42/150 downloaded
# 43/150 downloaded
# 44/150 downloaded
# 45/150 downloaded
# 46/150 downloaded
# 47/150 downloaded
# 48/150 downloaded
# 49/150 downloaded
# ...

# %%
import os
import requests

save_folder = "/content/gdrive/MyDrive/Food_Recognition_Project/dataset/cucumber"
os.makedirs(save_folder, exist_ok=True)

url = "https://api.github.com/repos/fruits-360/fruits-360-100x100/contents/Training"
folders = requests.get(url).json()

cucumber_folder = None

for item in folders:
    if item["type"] == "dir" and item["name"].lower().startswith("cucumber"):
        cucumber_folder = item
        break

if cucumber_folder is None:
    print("Cucumber folder not found")
else:
    print("Using folder:", cucumber_folder["name"])

    files = requests.get(cucumber_folder["url"]).json()

    images = [
        f for f in files
        if f["name"].lower().endswith((".jpg", ".jpeg", ".png"))
    ]

    images = images[:150]

    for number, image in enumerate(images, start=1):
        image_data = requests.get(image["download_url"]).content

        with open(os.path.join(save_folder, image["name"]), "wb") as f:
            f.write(image_data)

        print(f"{number}/{len(images)} downloaded")

    print("Cucumber finished!")
    print("Images saved:", len(os.listdir(save_folder)))
# Out:
# Using folder: Cucumber 1
# 1/150 downloaded
# 2/150 downloaded
# 3/150 downloaded
# 4/150 downloaded
# 5/150 downloaded
# 6/150 downloaded
# 7/150 downloaded
# 8/150 downloaded
# 9/150 downloaded
# 10/150 downloaded
# 11/150 downloaded
# 12/150 downloaded
# 13/150 downloaded
# 14/150 downloaded
# 15/150 downloaded
# 16/150 downloaded
# 17/150 downloaded
# 18/150 downloaded
# 19/150 downloaded
# 20/150 downloaded
# 21/150 downloaded
# 22/150 downloaded
# 23/150 downloaded
# 24/150 downloaded
# 25/150 downloaded
# 26/150 downloaded
# 27/150 downloaded
# 28/150 downloaded
# 29/150 downloaded
# 30/150 downloaded
# 31/150 downloaded
# 32/150 downloaded
# 33/150 downloaded
# 34/150 downloaded
# 35/150 downloaded
# 36/150 downloaded
# 37/150 downloaded
# 38/150 downloaded
# 39/150 downloaded
# 40/150 downloaded
# 41/150 downloaded
# 42/150 downloaded
# 43/150 downloaded
# 44/150 downloaded
# 45/150 downloaded
# 46/150 downloaded
# 47/150 downloaded
# 48/150 downloaded
# 49/150 downloaded
# ...

# %%
import os
import requests

save_folder = "/content/gdrive/MyDrive/Food_Recognition_Project/dataset/walnut"
os.makedirs(save_folder, exist_ok=True)

url = "https://api.github.com/repos/fruits-360/fruits-360-100x100/contents/Training"
folders = requests.get(url).json()

walnut_folder = None

for item in folders:
    if item["type"] == "dir" and item["name"].lower().startswith("walnut"):
        walnut_folder = item
        break

if walnut_folder is None:
    print("Walnut folder not found")
else:
    print("Using folder:", walnut_folder["name"])

    files = requests.get(walnut_folder["url"]).json()

    images = [
        f for f in files
        if f["name"].lower().endswith((".jpg", ".jpeg", ".png"))
    ]

    images = images[:150]

    for number, image in enumerate(images, start=1):
        image_data = requests.get(image["download_url"]).content

        with open(os.path.join(save_folder, image["name"]), "wb") as f:
            f.write(image_data)

        print(f"{number}/{len(images)} downloaded")

    print("Walnut finished!")
    print("Images saved:", len(os.listdir(save_folder)))
# Out:
# Using folder: Walnut 1
# 1/150 downloaded
# 2/150 downloaded
# 3/150 downloaded
# 4/150 downloaded
# 5/150 downloaded
# 6/150 downloaded
# 7/150 downloaded
# 8/150 downloaded
# 9/150 downloaded
# 10/150 downloaded
# 11/150 downloaded
# 12/150 downloaded
# 13/150 downloaded
# 14/150 downloaded
# 15/150 downloaded
# 16/150 downloaded
# 17/150 downloaded
# 18/150 downloaded
# 19/150 downloaded
# 20/150 downloaded
# 21/150 downloaded
# 22/150 downloaded
# 23/150 downloaded
# 24/150 downloaded
# 25/150 downloaded
# 26/150 downloaded
# 27/150 downloaded
# 28/150 downloaded
# 29/150 downloaded
# 30/150 downloaded
# 31/150 downloaded
# 32/150 downloaded
# 33/150 downloaded
# 34/150 downloaded
# 35/150 downloaded
# 36/150 downloaded
# 37/150 downloaded
# 38/150 downloaded
# 39/150 downloaded
# 40/150 downloaded
# 41/150 downloaded
# 42/150 downloaded
# 43/150 downloaded
# 44/150 downloaded
# 45/150 downloaded
# 46/150 downloaded
# 47/150 downloaded
# 48/150 downloaded
# 49/150 downloaded
# ...

# %%
import os
import requests
import zipfile
import glob
import shutil

# Download broccoli dataset
url = "https://ghaipublic.s3.us-west-2.amazonaws.com/datasets/broccoli_annotated.zip"

zip_path = "/content/broccoli.zip"
extract_folder = "/content/broccoli_data"

print("Downloading broccoli dataset...")

r = requests.get(url)
with open(zip_path, "wb") as f:
    f.write(r.content)

print("Download finished!")

# Extract
os.makedirs(extract_folder, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_folder)

print("Extract finished!")

# Find all images
images = glob.glob(extract_folder + "/**/*.jpg", recursive=True)
images += glob.glob(extract_folder + "/**/*.jpeg", recursive=True)
images += glob.glob(extract_folder + "/**/*.png", recursive=True)

print("Images found:", len(images))

# Google Drive broccoli folder
save_folder = "/content/gdrive/MyDrive/Food_Recognition_Project/dataset/broccoli"
os.makedirs(save_folder, exist_ok=True)

# Take only 150
images = images[:150]

for number, image in enumerate(images, start=1):

    new_name = f"broccoli_{number}.jpg"

    shutil.copy2(
        image,
        os.path.join(save_folder, new_name)
    )

print("Broccoli finished!")
print("Images saved:", len(os.listdir(save_folder)))
# Out:
# ...
# Download finished!
# Extract finished!
# Images found: 500
# Broccoli finished!
# Images saved: 150

# %%
import os

dataset_path = "/content/gdrive/MyDrive/Food_Recognition_Project/dataset"

for folder in sorted(os.listdir(dataset_path)):
    folder_path = os.path.join(dataset_path, folder)

    if os.path.isdir(folder_path):
        images = [
            f for f in os.listdir(folder_path)
            if f.lower().endswith((".jpg", ".jpeg", ".png"))
        ]

        print(folder, ":", len(images))
# Out:
# almond : 150
# apple : 150
# banana : 150
# broccoli : 150
# carrot : 150
# cashew : 51
# chocolate_cake : 152
# cucumber : 150
# cupcake : 152
# donut : 152
# french_fries : 152
# hamburger : 152
# hot_dog : 152
# ice_cream : 152
# orange : 150
# peanut : 91
# pizza : 154
# strawberry : 150
# tomato : 150
# walnut : 150

# %% [markdown]
# # 4. Dataset Check and Cleaning
#
# This section checks the number of images in each class, checks dataset balance, finds broken images, and checks image quality before training.

# %%
import os

dataset_path = "/content/gdrive/MyDrive/Food_Recognition_Project/dataset"

total = 0

for folder in sorted(os.listdir(dataset_path)):
    folder_path = os.path.join(dataset_path, folder)

    if os.path.isdir(folder_path):
        images = [
            f for f in os.listdir(folder_path)
            if f.lower().endswith((".jpg", ".jpeg", ".png"))
        ]

        print(f"{folder}: {len(images)}")
        total += len(images)

print("\nTotal internet images:", total)
# Out:
# almond: 150
# apple: 150
# banana: 150
# broccoli: 150
# carrot: 150
# cashew: 120
# chocolate_cake: 152
# cucumber: 150
# cupcake: 152
# donut: 152
# french_fries: 152
# hamburger: 152
# hot_dog: 152
# ice_cream: 152
# orange: 150
# peanut: 120
# pizza: 154
# strawberry: 150
# tomato: 150
# walnut: 150
#
# Total internet images: 2958

# %%
import os
from PIL import Image

dataset_path = "/content/gdrive/MyDrive/Food_Recognition_Project/dataset"

bad_images = []

for folder in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, folder)

    if not os.path.isdir(folder_path):
        continue

    for file in os.listdir(folder_path):

        if file.lower().endswith((".jpg", ".jpeg", ".png")):
            file_path = os.path.join(folder_path, file)

            try:
                img = Image.open(file_path)
                img.verify()
            except:
                bad_images.append(file_path)

print("Broken images found:", len(bad_images))

for image in bad_images[:20]:
    print(image)
# Out:
# Broken images found: 0

# %% [markdown]
# # 5. Self-Collected Data
#
# This section checks the additional food images that I manually collected and organized separately from the public datasets.

# %%
import os

self_path = "/content/gdrive/MyDrive/Food_Recognition_Project/Self-collected data"

total_self = 0

for folder in sorted(os.listdir(self_path)):
    folder_path = os.path.join(self_path, folder)

    if os.path.isdir(folder_path):
        images = [
            f for f in os.listdir(folder_path)
            if f.lower().endswith((".jpg", ".jpeg", ".png"))
        ]

        print(f"{folder}: {len(images)}")
        total_self += len(images)

print("\nTotal self-collected images:", total_self)
# Out:
# apple: 5
# banana: 5
# carrot: 5
# cashew: 5
# cucumber: 5
# ice_cream: 5
# orange: 5
# pizza: 5
#
# Total self-collected images: 40

# %% [markdown]
# # 6. Train, Validation and Test Split
#
# This section divides the dataset into training, validation, and testing sets before model training.

# %%
import os
import random
import shutil

random.seed(42)

source = "/content/gdrive/MyDrive/Food_Recognition_Project/dataset"
output = "/content/gdrive/MyDrive/Food_Recognition_Project/split_data"

for split in ["train", "validation", "test"]:
    os.makedirs(os.path.join(output, split), exist_ok=True)

classes = [
    folder for folder in os.listdir(source)
    if os.path.isdir(os.path.join(source, folder))
]

for class_name in classes:

    class_path = os.path.join(source, class_name)

    images = [
        f for f in os.listdir(class_path)
        if f.lower().endswith((".jpg", ".jpeg", ".png"))
    ]

    random.shuffle(images)

    total = len(images)

    train_end = int(total * 0.70)
    validation_end = train_end + int(total * 0.20)

    train_images = images[:train_end]
    validation_images = images[train_end:validation_end]
    test_images = images[validation_end:]

    for split_name, image_list in [
        ("train", train_images),
        ("validation", validation_images),
        ("test", test_images)
    ]:

        destination = os.path.join(
            output,
            split_name,
            class_name
        )

        os.makedirs(destination, exist_ok=True)

        for image in image_list:
            shutil.copy2(
                os.path.join(class_path, image),
                os.path.join(destination, image)
            )

    print(
        class_name,
        "| Train:", len(train_images),
        "| Validation:", len(validation_images),
        "| Test:", len(test_images)
    )

print("\nDataset split finished!")
# Out:
# pizza | Train: 107 | Validation: 30 | Test: 17
# hamburger | Train: 106 | Validation: 30 | Test: 16
# french_fries | Train: 106 | Validation: 30 | Test: 16
# hot_dog | Train: 106 | Validation: 30 | Test: 16
# apple | Train: 105 | Validation: 30 | Test: 15
# banana | Train: 105 | Validation: 30 | Test: 15
# orange | Train: 105 | Validation: 30 | Test: 15
# broccoli | Train: 105 | Validation: 30 | Test: 15
# tomato | Train: 105 | Validation: 30 | Test: 15
# cucumber | Train: 105 | Validation: 30 | Test: 15
# almond | Train: 105 | Validation: 30 | Test: 15
# peanut | Train: 84 | Validation: 24 | Test: 12
# cashew | Train: 84 | Validation: 24 | Test: 12
# walnut | Train: 105 | Validation: 30 | Test: 15
# donut | Train: 106 | Validation: 30 | Test: 16
# ice_cream | Train: 106 | Validation: 30 | Test: 16
# cupcake | Train: 106 | Validation: 30 | Test: 16
# chocolate_cake | Train: 106 | Validation: 30 | Test: 16
# strawberry | Train: 105 | Validation: 30 | Test: 15
# ...

# %%
split_path = "/content/gdrive/MyDrive/Food_Recognition_Project/split_data"

for split in ["train", "validation", "test"]:

    total = 0

    for class_name in os.listdir(os.path.join(split_path, split)):

        class_path = os.path.join(
            split_path,
            split,
            class_name
        )

        images = [
            f for f in os.listdir(class_path)
            if f.lower().endswith((".jpg", ".jpeg", ".png"))
        ]

        total += len(images)

    print(split, ":", total, "images")
# Out:
# train : 2067 images
# validation : 588 images
# test : 303 images

# %%
import os

self_path = "/content/gdrive/MyDrive/Food_Recognition_Project/Self-collected data"

total = 0

for folder in sorted(os.listdir(self_path)):
    folder_path = os.path.join(self_path, folder)

    if os.path.isdir(folder_path):
        images = [
            f for f in os.listdir(folder_path)
            if f.lower().endswith((".jpg", ".jpeg", ".png"))
        ]

        print(folder, ":", len(images))
        total += len(images)

print("\nTotal self-collected images:", total)
# Out:
# apple : 5
# banana : 5
# carrot : 5
# cashew : 5
# cucumber : 5
# ice_cream : 5
# orange : 5
# pizza : 5
#
# Total self-collected images: 40

# %%
import os
import random
import shutil

random.seed(42)

self_path = "/content/gdrive/MyDrive/Food_Recognition_Project/Self-collected data"
split_path = "/content/gdrive/MyDrive/Food_Recognition_Project/split_data"

for class_name in sorted(os.listdir(self_path)):

    class_folder = os.path.join(self_path, class_name)

    if not os.path.isdir(class_folder):
        continue

    images = [
        f for f in os.listdir(class_folder)
        if f.lower().endswith((".jpg", ".jpeg", ".png"))
    ]

    random.shuffle(images)

    # 5 images → 3 train, 1 validation, 1 test
    train_images = images[:3]
    validation_images = images[3:4]
    test_images = images[4:5]

    for split_name, image_list in [
        ("train", train_images),
        ("validation", validation_images),
        ("test", test_images)
    ]:

        destination = os.path.join(
            split_path,
            split_name,
            class_name
        )

        os.makedirs(destination, exist_ok=True)

        for i, image in enumerate(image_list):

            source_file = os.path.join(class_folder, image)

            # Add "self_" so we know this is self-collected data
            new_name = "self_" + image

            shutil.copy2(
                source_file,
                os.path.join(destination, new_name)
            )

    print(
        class_name,
        "| Train:", len(train_images),
        "| Validation:", len(validation_images),
        "| Test:", len(test_images)
    )

print("\nSelf-collected images added!")
# Out:
# apple | Train: 3 | Validation: 1 | Test: 1
# banana | Train: 3 | Validation: 1 | Test: 1
# carrot | Train: 3 | Validation: 1 | Test: 1
# cashew | Train: 3 | Validation: 1 | Test: 1
# cucumber | Train: 3 | Validation: 1 | Test: 1
# ice_cream | Train: 3 | Validation: 1 | Test: 1
# orange | Train: 3 | Validation: 1 | Test: 1
# pizza | Train: 3 | Validation: 1 | Test: 1
#
# Self-collected images added!

# %%
import os

for split in ["train", "validation", "test"]:

    total = 0

    split_folder = os.path.join(split_path, split)

    for class_name in os.listdir(split_folder):

        class_folder = os.path.join(split_folder, class_name)

        if os.path.isdir(class_folder):

            images = [
                f for f in os.listdir(class_folder)
                if f.lower().endswith((".jpg", ".jpeg", ".png"))
            ]

            total += len(images)

    print(split, ":", total, "images")
# Out:
# train : 2091 images
# validation : 596 images
# test : 311 images

# %% [markdown]
# 7. PyTorch DataLoader and MobileNetV2 Setup
#
# In this section, I prepare the dataset for PyTorch model training. I load the training, validation, and test datasets, apply image preprocessing and data augmentation, create DataLoaders, and set up a pretrained MobileNetV2 model for 20 food classes. I also check that the T4 GPU is available for faster training.

# %% [markdown]
# 7.1 Image Preprocessing and Data Augmentation
#
# This section prepares the images before training. All images are resized to 224×224 pixels, converted to tensors, and normalized. Training images also use simple data augmentation such as horizontal flipping and small rotation to help the model learn better.

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Using device:", device)
# Out:
# Using device: cuda

# %%
from torchvision import transforms

# Training images
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# Validation and testing images
val_test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

print("Image transformations ready!")
# Out:
# Image transformations ready!

# %% [markdown]
# What this code does
# Resize(224,224) → makes every image the correct size for MobileNetV2
# RandomHorizontalFlip() → sometimes flips training images
# RandomRotation(10) → slightly rotates training images
# ToTensor() → changes the image into data PyTorch can use
# Normalize() → prepares the image values for the pretrained MobileNetV2

# %% [markdown]
# 7.2 Load Train, Validation, and Test Datasets
#
# This section loads the training, validation, and testing image folders using PyTorch ImageFolder. The folder names are automatically used as the class labels for the 20 food classes.

# %%
import os
from torchvision import datasets

data_path = "/content/gdrive/MyDrive/Food_Recognition_Project/split_data"

train_dataset = datasets.ImageFolder(
    os.path.join(data_path, "train"),
    transform=train_transform
)

validation_dataset = datasets.ImageFolder(
    os.path.join(data_path, "validation"),
    transform=val_test_transform
)

test_dataset = datasets.ImageFolder(
    os.path.join(data_path, "test"),
    transform=val_test_transform
)

print("Train images:", len(train_dataset))
print("Validation images:", len(validation_dataset))
print("Test images:", len(test_dataset))

print("\nNumber of classes:", len(train_dataset.classes))
print(train_dataset.classes)
# Out:
# Train images: 2091
# Validation images: 596
# Test images: 311
#
# Number of classes: 20
# ['almond', 'apple', 'banana', 'broccoli', 'carrot', 'cashew', 'chocolate_cake', 'cucumber', 'cupcake', 'donut', 'french_fries', 'hamburger', 'hot_dog', 'ice_cream', 'orange', 'peanut', 'pizza', 'strawberry', 'tomato', 'walnut']

# %% [markdown]
# 7.3 Create PyTorch DataLoaders
#
# This section loads the dataset in small batches so the model can train efficiently without loading all images into memory at once.

# %%
from torch.utils.data import DataLoader

batch_size = 32

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=2
)

validation_loader = DataLoader(
    validation_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=2
)

test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=2
)

print("DataLoaders ready!")
print("Batch size:", batch_size)
# Out:
# DataLoaders ready!
# Batch size: 32

# %%
images, labels = next(iter(train_loader))

print("Image batch shape:", images.shape)
print("Label batch shape:", labels.shape)
# Out:
# Image batch shape: torch.Size([32, 3, 224, 224])
# Label batch shape: torch.Size([32])

# %% [markdown]
# 32 = 32 images in one batch
# 3 = RGB color channels
# 224 × 224 = image size for MobileNetV2
# Labels also contain 32 values, one label for each image

# %% [markdown]
# 7.4 Load and Prepare MobileNetV2
#
# This section loads a pretrained MobileNetV2 model, freezes the pretrained feature layers, and changes the final classifier to predict my 20 food classes.

# %%
import torch.nn as nn
from torchvision import models
from torchvision.models import MobileNet_V2_Weights

# Load pretrained MobileNetV2
weights = MobileNet_V2_Weights.DEFAULT
model = models.mobilenet_v2(weights=weights)

print("MobileNetV2 loaded!")
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-7ebf99e0.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-7ebf99e0.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 122MB/s]
# MobileNetV2 loaded!

# %%
for param in model.features.parameters():
    param.requires_grad = False

print("Pretrained feature layers frozen!")
# Out:
# Pretrained feature layers frozen!

# %% [markdown]
# Why?
#
# MobileNetV2 already learned useful image features from ImageNet, so we keep those features and train mainly the new food classifier.

# %%
num_classes = 20

model.classifier[1] = nn.Linear(
    model.last_channel,
    num_classes
)

model = model.to(device)

print("Model ready for", num_classes, "food classes!")
# Out:
# Model ready for 20 food classes!

# %%
images, labels = next(iter(train_loader))

images = images.to(device)

outputs = model(images)

print("Input shape:", images.shape)
print("Output shape:", outputs.shape)
# Out:
# Input shape: torch.Size([32, 3, 224, 224])
# Output shape: torch.Size([32, 20])

# %% [markdown]
# 7.5 Loss Function and Optimizer
#
# This section prepares the loss function and optimizer used to train the MobileNetV2 classifier. CrossEntropyLoss is used for multi-class classification, and Adam is used to update the model weights.

# %%
import torch.nn as nn
import torch.optim as optim

criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(
    model.classifier.parameters(),
    lr=0.001
)

print("Loss function: CrossEntropyLoss")
print("Optimizer: Adam")
print("Learning rate: 0.001")
# Out:
# Loss function: CrossEntropyLoss
# Optimizer: Adam
# Learning rate: 0.001

# %% [markdown]
# What these mean
#
# CrossEntropyLoss
# Measures how wrong the model prediction is.
#
# Adam optimizer
# Updates the model weights so the model can improve.
#
# Learning rate = 0.001
# Controls how big each update is during training.

# %% [markdown]
# 8. Model Training
#
# This section trains the MobileNetV2 model using the training dataset. After each epoch, the model is checked using the validation dataset. The best model is saved based on validation accuracy.

# %%
import os
model_dir = "/content/drive/MyDrive/Food_Recognition_Project/model"

os.makedirs(model_dir, exist_ok=True)

print("Model folder ready:", os.path.exists(model_dir))
# Out:
# Model folder ready: True

# %%
import os
import torch

model_dir = "/content/gdrive/MyDrive/Food_Recognition_Project/model"
os.makedirs(model_dir, exist_ok=True)

# Continue from Epoch 2 to Epoch 5
for epoch in range(1, num_epochs):

    # -------------------
    # TRAINING
    # -------------------
    model.train()

    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:

        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct / total

    # -------------------
    # VALIDATION
    # -------------------
    model.eval()

    val_running_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():

        for images, labels in validation_loader:

            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            val_running_loss += loss.item()

            _, predicted = torch.max(outputs, 1)

            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_loss = val_running_loss / len(validation_loader)
    val_accuracy = 100 * val_correct / val_total

    # Save results
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)

    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)

    print(f"Epoch {epoch+1}/{num_epochs}")
    print(
        f"Train Loss: {train_loss:.4f} | "
        f"Train Accuracy: {train_accuracy:.2f}%"
    )
    print(
        f"Validation Loss: {val_loss:.4f} | "
        f"Validation Accuracy: {val_accuracy:.2f}%"
    )

    # Save the best model
    if val_accuracy > best_val_accuracy:

        best_val_accuracy = val_accuracy

        torch.save(
            model.state_dict(),
            os.path.join(model_dir, "best_mobilenetv2.pth")
        )

        print("✅ New best model saved!")

    print("-" * 50)

print("\nTraining finished!")
print(f"Best Validation Accuracy: {best_val_accuracy:.2f}%")
# Out:
# Epoch 2/5
# Train Loss: 0.6171 | Train Accuracy: 89.53%
# Validation Loss: 0.5341 | Validation Accuracy: 87.75%
# ✅ New best model saved!
# --------------------------------------------------
# Epoch 3/5
# Train Loss: 0.4561 | Train Accuracy: 90.67%
# Validation Loss: 0.4493 | Validation Accuracy: 87.92%
# ✅ New best model saved!
# --------------------------------------------------
# Epoch 4/5
# Train Loss: 0.3807 | Train Accuracy: 91.34%
# Validation Loss: 0.3914 | Validation Accuracy: 89.09%
# ✅ New best model saved!
# --------------------------------------------------
# Epoch 5/5
# Train Loss: 0.3236 | Train Accuracy: 92.59%
# Validation Loss: 0.3770 | Validation Accuracy: 88.93%
# --------------------------------------------------
#
# Training finished!
# Best Validation Accuracy: 89.09%

# %% [markdown]
# The model trains for 5 epochs.
# One epoch means:
# The model goes through the whole training dataset once.

# %% [markdown]
# 8.1 Training and Validation Accuracy
#
# This graph shows how the training and validation accuracy changed during the five training epochs. It helps to check whether the model is learning correctly.

# %%
import matplotlib.pyplot as plt

epochs = range(1, num_epochs + 1)

plt.figure(figsize=(8, 5))

plt.plot(epochs, train_accuracies, marker='o', label="Training Accuracy")
plt.plot(epochs, val_accuracies, marker='o', label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Training and Validation Accuracy")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# 8.2 Training and Validation Loss
#
# This graph shows how the training and validation loss changed during training. A decreasing loss means the model is making fewer prediction errors.

# %%
plt.figure(figsize=(8, 5))

plt.plot(epochs, train_losses, marker='o', label="Training Loss")
plt.plot(epochs, val_losses, marker='o', label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# 9. Model Evaluation on Test Dataset
#
# This section evaluates the best trained MobileNetV2 model using the test dataset. The test images were not used during model training, so this result shows how well the model can recognize new food images.

# %%
import torch
import os

model_path = "/content/gdrive/MyDrive/Food_Recognition_Project/model/best_mobilenetv2.pth"

# Load the best model from Epoch 4
model.load_state_dict(torch.load(model_path, map_location=device))
model = model.to(device)

model.eval()

test_running_loss = 0.0
test_correct = 0
test_total = 0

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        loss = criterion(outputs, labels)
        test_running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)

        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

test_loss = test_running_loss / len(test_loader)
test_accuracy = 100 * test_correct / test_total

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.2f}%")
print(f"Correct Predictions: {test_correct}/{test_total}")
# Out:
# Test Loss: 0.3632
# Test Accuracy: 92.28%
# Correct Predictions: 287/311

# %% [markdown]
# Why do we reload the model?
#
# Becuz best model was at Epoch 4 = 89.09% validation accuracy.
#
# Epoch 5 was slightly lower at 88.93%, so we reload the saved Epoch 4 model before testing.

# %% [markdown]
# 9.1 Confusion Matrix
#
# This section checks which food classes the model predicts correctly and which classes are sometimes confused with each other.

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

all_labels = []
all_predictions = []

model.eval()

with torch.no_grad():
    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predicted = torch.max(outputs, 1)

        all_labels.extend(labels.cpu().numpy())
        all_predictions.extend(predicted.cpu().numpy())

class_names = train_dataset.classes

cm = confusion_matrix(all_labels, all_predictions)

fig, ax = plt.subplots(figsize=(14, 14))

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=class_names
)

disp.plot(
    ax=ax,
    xticks_rotation=90
)

plt.title("Confusion Matrix - Food Recognition")
plt.show()

# %% [markdown]
# How to understand it :
# The numbers on the diagonal are the correct predictions.
# The diagonal is the line of boxes that goes from the top-left to the bottom-right of the confusion matrix.

# %% [markdown]
# 9.2 Classification Report
#
# This section shows the performance of the model for each food class using precision, recall, F1-score, and the number of test images.

# %%
from sklearn.metrics import classification_report

report = classification_report(
    all_labels,
    all_predictions,
    target_names=class_names,
    digits=4
)

print(report)
# Out:
#                 precision    recall  f1-score   support
#
#         almond     1.0000    1.0000    1.0000        15
#          apple     1.0000    0.9375    0.9677        16
#         banana     1.0000    0.9375    0.9677        16
#       broccoli     1.0000    1.0000    1.0000        15
#         carrot     1.0000    0.9375    0.9677        16
#         cashew     1.0000    1.0000    1.0000        13
# chocolate_cake     0.8571    0.7500    0.8000        16
#       cucumber     1.0000    1.0000    1.0000        16
#        cupcake     0.6667    1.0000    0.8000        16
#          donut     0.8667    0.8125    0.8387        16
#   french_fries     0.8750    0.8750    0.8750        16
#      hamburger     0.7500    0.9375    0.8333        16
#        hot_dog     0.7857    0.6875    0.7333        16
#      ice_cream     1.0000    0.7647    0.8667        17
#         orange     1.0000    0.9375    0.9677        16
#         peanut     1.0000    1.0000    1.0000        12
# ...

# %% [markdown]
# Precision
# Of all images predicted as one food, how many were actually correct?
#
# Recall
# Of all real images of that food, how many did the model find correctly?
#
# F1-score
# A combined score of precision and recall. Higher is better.
#
# Support
# The number of test images for that food class.

# %% [markdown]
# My final test accuracy was 92.28% on 311 unseen images. The model performed very well on most classes. Some classes such as almond, broccoli, cucumber, peanut, strawberry, tomato, and walnut achieved perfect test performance. The weaker classes were hot dog, chocolate cake, cupcake, hamburger, and donut because some of these foods have similar visual features.

# %% [markdown]
# 10. Nutrition Data
#
# This section creates a nutrition database for the 20 food classes. Each food contains its category, estimated calories, protein, carbohydrates, and fat per 100 grams. The nutrition values are approximate because the exact portion size cannot be determined from a single image.

# %%
import os
import pandas as pd

nutrition_data = [
    ["almond", "Nuts", 579, 21.2, 21.6, 49.9],
    ["apple", "Fruit", 52, 0.3, 13.8, 0.2],
    ["banana", "Fruit", 89, 1.1, 22.8, 0.3],
    ["broccoli", "Vegetable", 34, 2.8, 6.6, 0.4],
    ["carrot", "Vegetable", 41, 0.9, 9.6, 0.2],
    ["cashew", "Nuts", 553, 18.2, 30.2, 43.9],
    ["chocolate_cake", "Dessert", 371, 5.3, 53.4, 15.7],
    ["cucumber", "Vegetable", 15, 0.7, 3.6, 0.1],
    ["cupcake", "Dessert", 305, 3.4, 50.7, 10.0],
    ["donut", "Dessert", 452, 4.9, 51.3, 25.0],
    ["french_fries", "Fast Food", 312, 3.4, 41.4, 15.0],
    ["hamburger", "Fast Food", 250, 13.0, 30.0, 9.0],
    ["hot_dog", "Fast Food", 290, 10.3, 4.2, 26.0],
    ["ice_cream", "Dessert", 207, 3.5, 23.6, 11.0],
    ["orange", "Fruit", 47, 0.9, 11.8, 0.1],
    ["peanut", "Nuts", 567, 25.8, 16.1, 49.2],
    ["pizza", "Fast Food", 266, 11.0, 33.0, 10.0],
    ["strawberry", "Fruit", 32, 0.7, 7.7, 0.3],
    ["tomato", "Vegetable", 18, 0.9, 3.9, 0.2],
    ["walnut", "Nuts", 654, 15.2, 13.7, 65.2]
]

columns = [
    "food",
    "category",
    "calories_kcal",
    "protein_g",
    "carbs_g",
    "fat_g"
]

nutrition_df = pd.DataFrame(nutrition_data, columns=columns)

nutrition_folder = "/content/gdrive/MyDrive/Food_Recognition_Project/nutrition"
os.makedirs(nutrition_folder, exist_ok=True)

nutrition_path = os.path.join(
    nutrition_folder,
    "food_nutrition.csv"
)

nutrition_df.to_csv(nutrition_path, index=False)

print("Nutrition database created!")
print("Number of foods:", len(nutrition_df))
print("Saved to:", nutrition_path)

nutrition_df
# Out:
# Nutrition database created!
# Number of foods: 20
# Saved to: /content/gdrive/MyDrive/Food_Recognition_Project/nutrition/food_nutrition.csv
#               food   category  calories_kcal  protein_g  carbs_g  fat_g
# 0           almond       Nuts            579       21.2     21.6   49.9
# 1            apple      Fruit             52        0.3     13.8    0.2
# 2           banana      Fruit             89        1.1     22.8    0.3
# 3         broccoli  Vegetable             34        2.8      6.6    0.4
# 4           carrot  Vegetable             41        0.9      9.6    0.2
# 5           cashew       Nuts            553       18.2     30.2   43.9
# 6   chocolate_cake    Dessert            371        5.3     53.4   15.7
# 7         cucumber  Vegetable             15        0.7      3.6    0.1
# 8          cupcake    Dessert            305        3.4     50.7   10.0
# 9            donut    Dessert            452        4.9     51.3   25.0
# ...

# %% [markdown]
# 10.1 Connect Model Prediction with Nutrition
#
# This section connects the MobileNetV2 prediction with the nutrition database. After the model recognizes a food image, the system finds the predicted food in the nutrition table and displays its category, confidence score, calories, protein, carbohydrates, and fat per 100g.

# %%
import random
import torch
import matplotlib.pyplot as plt

# Convert nutrition table to dictionary
nutrition_dict = nutrition_df.set_index("food").to_dict("index")

# Select one random test image
idx = random.randint(0, len(test_dataset) - 1)

image, true_label = test_dataset[idx]

# Prepare image for model
input_image = image.unsqueeze(0).to(device)

model.eval()

with torch.no_grad():

    output = model(input_image)

    probabilities = torch.softmax(output, dim=1)

    confidence, predicted_label = torch.max(
        probabilities, 1
    )

predicted_food = class_names[predicted_label.item()]
actual_food = class_names[true_label]

confidence_percent = confidence.item() * 100

# Get nutrition information
nutrition = nutrition_dict[predicted_food]

print("Predicted Food:", predicted_food.replace("_", " ").title())
print("Actual Food:", actual_food.replace("_", " ").title())
print(f"Confidence: {confidence_percent:.2f}%")

print("\nNutrition per 100g")
print("----------------------")
print("Category:", nutrition["category"])
print("Calories:", nutrition["calories_kcal"], "kcal")
print("Protein:", nutrition["protein_g"], "g")
print("Carbohydrates:", nutrition["carbs_g"], "g")
print("Fat:", nutrition["fat_g"], "g")
# Out:
# Predicted Food: Peanut
# Actual Food: Peanut
# Confidence: 95.55%
#
# Nutrition per 100g
# ----------------------
# Category: Nuts
# Calories: 567 kcal
# Protein: 25.8 g
# Carbohydrates: 16.1 g
# Fat: 49.2 g

# %%
display_image = image.permute(1, 2, 0)

mean = torch.tensor([0.485, 0.456, 0.406])
std = torch.tensor([0.229, 0.224, 0.225])

display_image = display_image * std + mean
display_image = torch.clamp(display_image, 0, 1)

plt.figure(figsize=(5, 5))
plt.imshow(display_image)

plt.title(
    f"{predicted_food.replace('_', ' ').title()}\n"
    f"Confidence: {confidence_percent:.2f}%"
)

plt.axis("off")
plt.show()

# %% [markdown]
# 10.2 Nutrition Estimation by Portion Size
#
# This section allows the user to enter an estimated food portion in grams. The system then calculates calories, protein, carbohydrates, and fat based on that portion size.

# %%
portion_grams = float(input("Enter estimated portion size in grams: "))

ratio = portion_grams / 100

estimated_calories = nutrition["calories_kcal"] * ratio
estimated_protein = nutrition["protein_g"] * ratio
estimated_carbs = nutrition["carbs_g"] * ratio
estimated_fat = nutrition["fat_g"] * ratio

print("\nEstimated Nutrition")
print("----------------------")
print("Food:", predicted_food.replace("_", " ").title())
print("Portion Size:", portion_grams, "g")
print(f"Calories: {estimated_calories:.2f} kcal")
print(f"Protein: {estimated_protein:.2f} g")
print(f"Carbohydrates: {estimated_carbs:.2f} g")
print(f"Fat: {estimated_fat:.2f} g")
# Out:
# Enter estimated portion size in grams: 200
#
# Estimated Nutrition
# ----------------------
# Food: Peanut
# Portion Size: 200.0 g
# Calories: 1134.00 kcal
# Protein: 51.60 g
# Carbohydrates: 32.20 g
# Fat: 98.40 g

# %% [markdown]
# 11. Final Food Prediction Function
#
# This section combines the trained MobileNetV2 model with the nutrition database. The function accepts a food image and portion size, predicts the food class and confidence score, and displays the estimated nutritional information.

# %%
import torch
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from torchvision import transforms

# Class names must follow the same order used during training
class_names = [
    'almond', 'apple', 'banana', 'broccoli', 'carrot',
    'cashew', 'chocolate_cake', 'cucumber', 'cupcake',
    'donut', 'french_fries', 'hamburger', 'hot_dog',
    'ice_cream', 'orange', 'peanut', 'pizza',
    'strawberry', 'tomato', 'walnut'
]

# Load nutrition database
nutrition_path = "/content/gdrive/MyDrive/Food_Recognition_Project/nutrition/food_nutrition.csv"

nutrition_df = pd.read_csv(nutrition_path)
nutrition_dict = nutrition_df.set_index("food").to_dict("index")

# Transformation for new images
prediction_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])


def predict_food(image_path, portion_grams=100):

    # Load image
    original_image = Image.open(image_path).convert("RGB")

    # Prepare image
    image_tensor = prediction_transform(original_image)
    image_tensor = image_tensor.unsqueeze(0).to(device)

    # Prediction
    model.eval()

    with torch.no_grad():

        output = model(image_tensor)

        probabilities = torch.softmax(output, dim=1)

        confidence, predicted_label = torch.max(
            probabilities, 1
        )

    predicted_food = class_names[predicted_label.item()]
    confidence_percent = confidence.item() * 100

    # Nutrition information
    nutrition = nutrition_dict[predicted_food]

    ratio = portion_grams / 100

    calories = nutrition["calories_kcal"] * ratio
    protein = nutrition["protein_g"] * ratio
    carbs = nutrition["carbs_g"] * ratio
    fat = nutrition["fat_g"] * ratio

    # Display result
    print("=" * 35)
    print("FOOD RECOGNITION RESULT")
    print("=" * 35)

    print(
        "Food:",
        predicted_food.replace("_", " ").title()
    )

    print(
        f"Confidence: {confidence_percent:.2f}%"
    )

    print(
        "Category:",
        nutrition["category"]
    )

    print("\nEstimated Nutrition")
    print("----------------------")

    print(f"Portion Size: {portion_grams} g")
    print(f"Calories: {calories:.2f} kcal")
    print(f"Protein: {protein:.2f} g")
    print(f"Carbohydrates: {carbs:.2f} g")
    print(f"Fat: {fat:.2f} g")

    # Display image
    plt.figure(figsize=(5, 5))

    plt.imshow(original_image)

    plt.title(
        f"{predicted_food.replace('_', ' ').title()}\n"
        f"Confidence: {confidence_percent:.2f}%"
    )

    plt.axis("off")
    plt.show()

# %% [markdown]
# 11.1 Test with a New Food Image
#
# This section allows the user to upload a new food image and test the complete food recognition and nutrition estimation system.

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-7f4e34ec-3b11-4eae-965e-fb9e5fde859c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f4e34ec-3b11-4eae-965e-fb9e5fde859c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 11.2 Run Final Prediction

# %%
uploaded_filename = list(uploaded.keys())[0]

portion = float(
    input("Enter estimated portion size in grams: ")
)

predict_food(
    uploaded_filename,
    portion_grams=portion
)
# Out:
# Enter estimated portion size in grams: 150
# ...
# FOOD RECOGNITION RESULT
# ...
# Food: Cupcake
# Confidence: 76.15%
# Category: Dessert
#
# Estimated Nutrition
# ----------------------
# Portion Size: 150.0 g
# Calories: 457.50 kcal
# Protein: 5.10 g
# Carbohydrates: 76.05 g
# Fat: 15.00 g

# %% [markdown]
# 12. Fine-Tuning MobileNetV2
#
# This section fine-tunes the last layers of the pretrained MobileNetV2 model. Instead of keeping all feature layers frozen, I allow the last few layers to learn from my food dataset using a smaller learning rate.

# %%
# Freeze all feature layers first
for param in model.features.parameters():
    param.requires_grad = False

# Unfreeze the last 3 feature blocks
for layer in model.features[-3:]:
    for param in layer.parameters():
        param.requires_grad = True

print("Last 3 MobileNetV2 feature blocks are ready for fine-tuning.")
# Out:
# Last 3 MobileNetV2 feature blocks are ready for fine-tuning.

# %%
import torch.optim as optim

optimizer = optim.Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=0.0001
)

print("Fine-tuning optimizer ready!")
print("Learning rate: 0.0001")
# Out:
# Fine-tuning optimizer ready!
# Learning rate: 0.0001

# %% [markdown]
# Why use 0.0001 now?
# Before, we used:0.001
# For fine-tuning we use a smaller learning rate:0.0001
# because the pretrained layers already contain useful knowledge. We only want to adjust them a little, not change them too much.

# %% [markdown]
# 12.1 Fine-Tune the Model
#
# This section trains the last few MobileNetV2 feature layers for 3 additional epochs using a smaller learning rate. The validation accuracy is checked after each epoch, and the best fine-tuned model is saved separately.

# %%
fine_tune_epochs = 3

best_fine_val_accuracy = 0.0

fine_train_accuracies = []
fine_val_accuracies = []

for epoch in range(fine_tune_epochs):

    # -------------------
    # TRAINING
    # -------------------
    model.train()

    correct = 0
    total = 0
    running_loss = 0.0

    for images, labels in train_loader:

        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct / total

    # -------------------
    # VALIDATION
    # -------------------
    model.eval()

    val_correct = 0
    val_total = 0
    val_running_loss = 0.0

    with torch.no_grad():

        for images, labels in validation_loader:

            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            val_running_loss += loss.item()

            _, predicted = torch.max(outputs, 1)

            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_loss = val_running_loss / len(validation_loader)
    val_accuracy = 100 * val_correct / val_total

    fine_train_accuracies.append(train_accuracy)
    fine_val_accuracies.append(val_accuracy)

    print(f"Fine-Tune Epoch {epoch+1}/{fine_tune_epochs}")
    print(
        f"Train Loss: {train_loss:.4f} | "
        f"Train Accuracy: {train_accuracy:.2f}%"
    )
    print(
        f"Validation Loss: {val_loss:.4f} | "
        f"Validation Accuracy: {val_accuracy:.2f}%"
    )

    # Save best fine-tuned model
    if val_accuracy > best_fine_val_accuracy:

        best_fine_val_accuracy = val_accuracy

        torch.save(
            model.state_dict(),
            "/content/drive/MyDrive/Food_Recognition_Project/model/best_finetuned_mobilenetv2.pth"
        )

        print("✅ Best fine-tuned model saved!")

    print("-" * 50)

print("\nFine-tuning finished!")
print(f"Best Fine-Tuned Validation Accuracy: {best_fine_val_accuracy:.2f}%")
# Out:
# Fine-Tune Epoch 1/3
# Train Loss: 0.2775 | Train Accuracy: 93.07%
# Validation Loss: 0.2842 | Validation Accuracy: 90.60%
# ✅ Best fine-tuned model saved!
# --------------------------------------------------
# Fine-Tune Epoch 2/3
# Train Loss: 0.1943 | Train Accuracy: 94.12%
# Validation Loss: 0.2551 | Validation Accuracy: 90.27%
# --------------------------------------------------
# Fine-Tune Epoch 3/3
# Train Loss: 0.1510 | Train Accuracy: 96.08%
# Validation Loss: 0.2435 | Validation Accuracy: 91.61%
# ✅ Best fine-tuned model saved!
# --------------------------------------------------
#
# Fine-tuning finished!
# Best Fine-Tuned Validation Accuracy: 91.61%

# %% [markdown]
# 12.2 Evaluate the Fine-Tuned Model
#
# This section evaluates the best fine-tuned MobileNetV2 model using the same test dataset. The result is compared with the original model to check whether fine-tuning improved the final performance.

# %%
fine_model_path = "/content/drive/MyDrive/Food_Recognition_Project/model/best_finetuned_mobilenetv2.pth"

# Load the best fine-tuned model
model.load_state_dict(
    torch.load(fine_model_path, map_location=device)
)

model = model.to(device)
model.eval()

fine_test_loss = 0.0
fine_test_correct = 0
fine_test_total = 0

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        loss = criterion(outputs, labels)
        fine_test_loss += loss.item()

        _, predicted = torch.max(outputs, 1)

        fine_test_total += labels.size(0)
        fine_test_correct += (predicted == labels).sum().item()

fine_test_loss = fine_test_loss / len(test_loader)

fine_test_accuracy = (
    100 * fine_test_correct / fine_test_total
)

print(f"Fine-Tuned Test Loss: {fine_test_loss:.4f}")
print(f"Fine-Tuned Test Accuracy: {fine_test_accuracy:.2f}%")
print(
    f"Correct Predictions: "
    f"{fine_test_correct}/{fine_test_total}"
)

print("\nComparison")
print("----------------------")
print("Original Test Accuracy: 92.28%")
print(
    f"Fine-Tuned Test Accuracy: "
    f"{fine_test_accuracy:.2f}%"
)
# Out:
# Fine-Tuned Test Loss: 0.1908
# Fine-Tuned Test Accuracy: 95.18%
# Correct Predictions: 296/311
#
# Comparison
# ----------------------
# Original Test Accuracy: 92.28%
# Fine-Tuned Test Accuracy: 95.18%

# %% [markdown]
# How we decide which model to keep
#
# If fine-tuned accuracy is:
# higher than 92.28% → use the fine-tuned model
#
# If it is:
# lower than 92.28% → keep the original model
#
# Fine-tuning does not always guarantee better test accuracy, so we test before deciding.
#
# Fine-tuning improved my model performance by 2.90 percentage points on the unseen test dataset.

# %% [markdown]
# 13. Fine-Tuned Model Evaluation
#
# This section evaluates the fine-tuned MobileNetV2 model before further real-world improvement. It generates the classification report and confusion matrix for comparison with the later improved model.

# %%
import os
import torch
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix

results_dir = "/content/drive/MyDrive/Food_Recognition_Project/results"
os.makedirs(results_dir, exist_ok=True)

# Load fine-tuned model before further improvement
final_model_path = "/content/drive/MyDrive/Food_Recognition_Project/model/best_finetuned_mobilenetv2.pth"

model.load_state_dict(
    torch.load(final_model_path, map_location=device)
)

model = model.to(device)
model.eval()

all_labels = []
all_predictions = []

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predicted = torch.max(outputs, 1)

        all_labels.extend(labels.cpu().numpy())
        all_predictions.extend(predicted.cpu().numpy())

print("Final model predictions completed!")
print("Total test images:", len(all_labels))
# Out:
# Final model predictions completed!
# Total test images: 311

# %% [markdown]
# 13.1 Final Classification Report
#
# This section shows precision, recall, and F1-score for each of the 20 food classes using the final fine-tuned model.

# %%
report = classification_report(
    all_labels,
    all_predictions,
    target_names=class_names,
    digits=4,
    output_dict=True
)

report_df = pd.DataFrame(report).transpose()

display(report_df)

report_path = os.path.join(
    results_dir,
    "final_classification_report.csv"
)

report_df.to_csv(report_path)

print("Classification report saved!")
print(report_path)
# Out:
#                 precision    recall  f1-score     support
# almond           1.000000  1.000000  1.000000   15.000000
# apple            1.000000  1.000000  1.000000   16.000000
# banana           0.941176  1.000000  0.969697   16.000000
# broccoli         1.000000  1.000000  1.000000   15.000000
# carrot           1.000000  0.937500  0.967742   16.000000
# cashew           1.000000  0.923077  0.960000   13.000000
# chocolate_cake   0.800000  0.750000  0.774194   16.000000
# cucumber         1.000000  1.000000  1.000000   16.000000
# cupcake          0.789474  0.937500  0.857143   16.000000
# donut            0.875000  0.875000  0.875000   16.000000
# french_fries     1.000000  0.875000  0.933333   16.000000
# hamburger        1.000000  0.875000  0.933333   16.000000
# hot_dog          0.937500  0.937500  0.937500   16.000000
# ice_cream        0.941176  0.941176  0.941176   17.000000
# orange           1.000000  1.000000  1.000000   16.000000
# ...

# %% [markdown]
# 13.2 Final Confusion Matrix
#
# This confusion matrix shows the correct and incorrect predictions of the final fine-tuned model for all 20 food classes.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(
    all_labels,
    all_predictions
)

fig, ax = plt.subplots(figsize=(14, 14))

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=class_names
)

disp.plot(
    ax=ax,
    xticks_rotation=90
)

plt.title("Final Fine-Tuned Model Confusion Matrix")
plt.tight_layout()

confusion_path = os.path.join(
    results_dir,
    "final_confusion_matrix.png"
)

plt.savefig(
    confusion_path,
    dpi=300,
    bbox_inches="tight"
)

plt.show()

print("Confusion matrix saved!")
# Out:
# Confusion matrix saved!

# %% [markdown]
# This is the confusion matrix of my final fine-tuned MobileNetV2 model. Most values are on the diagonal, meaning the model correctly recognized most food images. There are only a small number of misclassifications between visually similar foods. The final model correctly classified 296 out of 311 test images and achieved 95.18% test accuracy.

# %% [markdown]
# 13.3 Original vs Fine-Tuned Model Comparison
#
# This section compares the test accuracy before and after fine-tuning to show the improvement in model performance.

# %%
comparison_data = {
    "Model": [
        "Original MobileNetV2",
        "Fine-Tuned MobileNetV2"
    ],
    "Test Accuracy (%)": [
        92.28,
        95.18
    ]
}

comparison_df = pd.DataFrame(comparison_data)

display(comparison_df)

comparison_path = os.path.join(
    results_dir,
    "model_comparison.csv"
)

comparison_df.to_csv(
    comparison_path,
    index=False
)

print("Model comparison saved!")
# Out:
#                     Model  Test Accuracy (%)
# 0    Original MobileNetV2              92.28
# 1  Fine-Tuned MobileNetV2              95.18
# Model comparison saved!

# %% [markdown]
# 1. Save the Day 7 accuracy graph

# %%
import os
import matplotlib.pyplot as plt

results_dir = "/content/drive/MyDrive/Food_Recognition_Project/results"
os.makedirs(results_dir, exist_ok=True)

epochs = range(1, len(train_accuracies) + 1)

plt.figure(figsize=(8, 5))

plt.plot(
    epochs,
    train_accuracies,
    marker="o",
    label="Training Accuracy"
)

plt.plot(
    epochs,
    val_accuracies,
    marker="o",
    label="Validation Accuracy"
)

plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Training and Validation Accuracy")
plt.legend()
plt.grid()

plt.savefig(
    os.path.join(results_dir, "training_accuracy.png"),
    dpi=300,
    bbox_inches="tight"
)

plt.show()

print("Training accuracy graph saved!")
# Out:
# Training accuracy graph saved!

# %% [markdown]
# 2. Save the Day 7 loss graph

# %%
plt.figure(figsize=(8, 5))

plt.plot(
    epochs,
    train_losses,
    marker="o",
    label="Training Loss"
)

plt.plot(
    epochs,
    val_losses,
    marker="o",
    label="Validation Loss"
)

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.grid()

plt.savefig(
    os.path.join(results_dir, "training_loss.png"),
    dpi=300,
    bbox_inches="tight"
)

plt.show()

print("Training loss graph saved!")
# Out:
# Training loss graph saved!

# %% [markdown]
# 3. Save the ORIGINAL confusion matrix

# %%
import torch
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

original_model_path = (
    "/content/drive/MyDrive/Food_Recognition_Project/"
    "model/best_mobilenetv2.pth"
)

# Load original model
model.load_state_dict(
    torch.load(original_model_path, map_location=device)
)

model = model.to(device)
model.eval()

original_labels = []
original_predictions = []

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predicted = torch.max(outputs, 1)

        original_labels.extend(labels.cpu().numpy())
        original_predictions.extend(predicted.cpu().numpy())

original_cm = confusion_matrix(
    original_labels,
    original_predictions
)

fig, ax = plt.subplots(figsize=(14, 14))

disp = ConfusionMatrixDisplay(
    confusion_matrix=original_cm,
    display_labels=class_names
)

disp.plot(
    ax=ax,
    xticks_rotation=90
)

plt.title("Original MobileNetV2 Confusion Matrix")
plt.tight_layout()

plt.savefig(
    os.path.join(
        results_dir,
        "original_confusion_matrix.png"
    ),
    dpi=300,
    bbox_inches="tight"
)

plt.show()

print("Original confusion matrix saved!")
# Out:
# Original confusion matrix saved!

# %% [markdown]
# 4. Reload Final Improved Model

# %%
final_model_path = (
    "/content/drive_new/MyDrive/Food_Recognition_Project/"
    "model/best_improved_mobilenetv2.pth"
)
model.load_state_dict(
    torch.load(final_model_path, map_location=device)
)

model = model.to(device)
model.eval()

print("Final improved model loaded again!")
# Out:
# Final fine-tuned model loaded again!

# %% [markdown]
# 5. Save a prediction example

# %%
import random
import torch
import matplotlib.pyplot as plt

idx = random.randint(0, len(test_dataset) - 1)

image, true_label = test_dataset[idx]

input_image = image.unsqueeze(0).to(device)

model.eval()

with torch.no_grad():

    output = model(input_image)

    probabilities = torch.softmax(output, dim=1)

    confidence, predicted_label = torch.max(
        probabilities,
        1
    )

predicted_food = class_names[predicted_label.item()]
actual_food = class_names[true_label]

confidence_percent = confidence.item() * 100

# Convert image back for display
display_image = image.permute(1, 2, 0)

mean = torch.tensor([0.485, 0.456, 0.406])
std = torch.tensor([0.229, 0.224, 0.225])

display_image = display_image * std + mean
display_image = torch.clamp(display_image, 0, 1)

plt.figure(figsize=(6, 6))

plt.imshow(display_image)

plt.title(
    f"Predicted: {predicted_food.replace('_', ' ').title()}\n"
    f"Actual: {actual_food.replace('_', ' ').title()}\n"
    f"Confidence: {confidence_percent:.2f}%"
)

plt.axis("off")

plt.savefig(
    os.path.join(
        results_dir,
        "prediction_example.png"
    ),
    dpi=300,
    bbox_inches="tight"
)

plt.show()

print("Prediction example saved!")
# Out:
# Prediction example saved!

# %%
import os

results_dir = "/content/drive/MyDrive/Food_Recognition_Project/results"
prediction_path = os.path.join(results_dir, "prediction_example.png")

print("Prediction file exists:", os.path.exists(prediction_path))
print("Files in results folder:")
print(os.listdir(results_dir))
# Out:
# Prediction file exists: True
# Files in results folder:
# ['final_classification_report.csv', 'final_confusion_matrix.png', 'model_comparison.csv', 'training_accuracy.png', 'training_loss.png', 'original_confusion_matrix.png', 'prediction_example.png']

# %%
import os
import torch

model_dir = "/content/drive/MyDrive/Food_Recognition_Project/model"
os.makedirs(model_dir, exist_ok=True)

torch.save(
    model.state_dict(),
    os.path.join(model_dir, "best_finetuned_mobilenetv2.pth")
)

print("Final model saved to Google Drive!")
# Out:
# Final model saved to Google Drive!

# %% [markdown]
# 13.4 Prepare New Demo Images

# %% [markdown]
# 14. Test Final Model with New Images
#
# This section tests the improved MobileNetV2 model using new food images from the test_images folder. For each image, the system predicts the food class, confidence score, and category to evaluate real-world performance.

# %%
import os
import torch
import pandas as pd
from PIL import Image
from torchvision import models, transforms
import torch.nn as nn

# -------------------------
# Paths
# -------------------------
test_images_dir = "/content/gdrive/MyDrive/Food_Recognition_Project/test_images"
model_path = "/content/gdrive/MyDrive/Food_Recognition_Project/model/best_finetuned_mobilenetv2.pth"
nutrition_path = "/content/gdrive/MyDrive/Food_Recognition_Project/nutrition/food_nutrition.csv"
results_dir = "/content/gdrive/MyDrive/Food_Recognition_Project/results"

os.makedirs(results_dir, exist_ok=True)

# -------------------------
# Device
# -------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# -------------------------
# Class names
# -------------------------
class_names = [
    'almond', 'apple', 'banana', 'broccoli', 'carrot',
    'cashew', 'chocolate_cake', 'cucumber', 'cupcake',
    'donut', 'french_fries', 'hamburger', 'hot_dog',
    'ice_cream', 'orange', 'peanut', 'pizza',
    'strawberry', 'tomato', 'walnut'
]

# -------------------------
# Create MobileNetV2 model
# -------------------------
model = models.mobilenet_v2(weights=None)

model.classifier[1] = nn.Linear(
    model.last_channel,
    len(class_names)
)

model.load_state_dict(
    torch.load(model_path, map_location=device)
)

model = model.to(device)
model.eval()

# -------------------------
# Image transformation
# -------------------------
prediction_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# -------------------------
# Nutrition data
# -------------------------
nutrition_df = pd.read_csv(nutrition_path)
nutrition_dict = nutrition_df.set_index("food").to_dict("index")

# -------------------------
# Test every image
# -------------------------
results = []

image_extensions = (".jpg", ".jpeg", ".png", ".webp")

for filename in sorted(os.listdir(test_images_dir)):

    if not filename.lower().endswith(image_extensions):
        continue

    image_path = os.path.join(test_images_dir, filename)

    image = Image.open(image_path).convert("RGB")

    image_tensor = prediction_transform(image)
    image_tensor = image_tensor.unsqueeze(0).to(device)

    with torch.no_grad():
        output = model(image_tensor)
        probabilities = torch.softmax(output, dim=1)

        confidence, predicted_label = torch.max(
            probabilities,
            1
        )

    predicted_food = class_names[predicted_label.item()]
    confidence_percent = confidence.item() * 100

    category = nutrition_dict[predicted_food]["category"]

    results.append([
        filename,
        predicted_food.replace("_", " ").title(),
        confidence_percent,
        category
    ])

# -------------------------
# Create result table
# -------------------------
demo_results_df = pd.DataFrame(
    results,
    columns=[
        "Image",
        "Predicted Food",
        "Confidence (%)",
        "Category"
    ]
)

demo_results_df["Confidence (%)"] = (
    demo_results_df["Confidence (%)"].round(2)
)

display(demo_results_df)

# -------------------------
# Save result
# -------------------------
demo_result_path = os.path.join(
    results_dir,
    "demo_test_results.csv"
)

demo_results_df.to_csv(
    demo_result_path,
    index=False
)

print("\nTotal new images tested:", len(demo_results_df))
print("Demo results saved!")
print(demo_result_path)
# Out:
#                   Image  Predicted Food  Confidence (%)   Category
# 0        apple_test.jpg           Donut           20.82    Dessert
# 1       banana_test.jpg          Banana           73.29      Fruit
# 2       carrot_test.jpg  Chocolate Cake           38.42    Dessert
# 3      cupcake_test.jpg         Cupcake           96.16    Dessert
# 4        donut_test.jpg  Chocolate Cake           53.89    Dessert
# 5    hamburger_test.jpg           Donut           45.09    Dessert
# 6      hot_dog_test.jpg         Hot Dog           88.20  Fast Food
# 7    ice_cream_test.jpg       Ice Cream           41.81    Dessert
# 8       peanut_test.jpg    French Fries           45.91  Fast Food
# 9        pizza_test.jpg           Pizza           99.24  Fast Food
# 10  strawberry_test.jpg  Chocolate Cake           26.54    Dessert
# Total new images tested: 11
# Demo results saved!
# /content/gdrive/MyDrive/Food_Recognition_Project/results/demo_test_results.csv

# %% [markdown]
# 14.1 Real-World Prediction Analysis
#
# I tested the final model using completely new internet images that were not included in the original dataset. The model performed worse than on the formal test dataset, showing that some new real-world images are more difficult because of differences in background, lighting, angle, and food appearance.

# %%
actual_labels = [
    "apple",
    "banana",
    "carrot",
    "cupcake",
    "donut",
    "hamburger",
    "hot_dog",
    "ice_cream",
    "peanut",
    "pizza",
    "strawberry"
]

predicted_labels = [
    "donut",
    "banana",
    "chocolate_cake",
    "cupcake",
    "chocolate_cake",
    "donut",
    "hot_dog",
    "ice_cream",
    "french_fries",
    "pizza",
    "chocolate_cake"
]

correct = 0

for actual, predicted in zip(actual_labels, predicted_labels):
    if actual == predicted:
        correct += 1

demo_accuracy = correct / len(actual_labels) * 100

print("Correct predictions:", correct, "/", len(actual_labels))
print(f"New Image Demo Accuracy: {demo_accuracy:.2f}%")
# Out:
# Correct predictions: 5 / 11
# New Image Demo Accuracy: 45.45%

# %% [markdown]
# 14.2 Confidence Threshold for Uncertain Predictions
#
# This section adds a confidence threshold to make the system more reliable. If the model confidence is below 50%, the system shows "Uncertain Prediction" and does not display category or nutrition information.

# %%
def predict_food(image_path, portion_grams=100):

    # Load image
    original_image = Image.open(image_path).convert("RGB")

    # Prepare image
    image_tensor = prediction_transform(original_image)
    image_tensor = image_tensor.unsqueeze(0).to(device)

    # Prediction
    model.eval()

    with torch.no_grad():

        output = model(image_tensor)

        probabilities = torch.softmax(output, dim=1)

        confidence, predicted_label = torch.max(
            probabilities, 1
        )

    predicted_food = class_names[predicted_label.item()]
    confidence_percent = confidence.item() * 100

    print("=" * 35)
    print("FOOD RECOGNITION RESULT")
    print("=" * 35)

    # ----------------------------------
    # LOW CONFIDENCE
    # ----------------------------------
    if confidence_percent < 50:

        print("Result: Uncertain Prediction")
        print(
            "Top Prediction:",
            predicted_food.replace("_", " ").title()
        )
        print(f"Confidence: {confidence_percent:.2f}%")

        print("\nThe confidence is too low.")
        print("Category and nutrition are not shown.")

        plt.figure(figsize=(5, 5))
        plt.imshow(original_image)

        plt.title(
            f"Uncertain Prediction\n"
            f"Confidence: {confidence_percent:.2f}%"
        )

        plt.axis("off")
        plt.show()

        return

    # ----------------------------------
    # CONFIDENT PREDICTION
    # ----------------------------------
    nutrition = nutrition_dict[predicted_food]

    ratio = portion_grams / 100

    calories = nutrition["calories_kcal"] * ratio
    protein = nutrition["protein_g"] * ratio
    carbs = nutrition["carbs_g"] * ratio
    fat = nutrition["fat_g"] * ratio

    print(
        "Food:",
        predicted_food.replace("_", " ").title()
    )

    print(f"Confidence: {confidence_percent:.2f}%")
    print("Category:", nutrition["category"])

    print("\nEstimated Nutrition")
    print("----------------------")
    print(f"Portion Size: {portion_grams} g")
    print(f"Calories: {calories:.2f} kcal")
    print(f"Protein: {protein:.2f} g")
    print(f"Carbohydrates: {carbs:.2f} g")
    print(f"Fat: {fat:.2f} g")

    plt.figure(figsize=(5, 5))
    plt.imshow(original_image)

    plt.title(
        f"{predicted_food.replace('_', ' ').title()}\n"
        f"Confidence: {confidence_percent:.2f}%"
    )

    plt.axis("off")
    plt.show()

# %%
predict_food(
    "/content/drive/MyDrive/Food_Recognition_Project/test_images/apple_test.jpg",
    portion_grams=100
)
# Out:
# ...
# FOOD RECOGNITION RESULT
# ...
# Result: Uncertain Prediction
# Top Prediction: Donut
# Confidence: 20.82%
#
# The confidence is too low.
# Category and nutrition are not shown.

# %% [markdown]
# 15. Real-World Model Improvement
#
# After testing the model with completely new images, I found several food classes that were difficult to recognize. To improve generalization, I collect additional diverse images for the weak classes. These new images are added only to the training data, while the original real-world test images remain unchanged.

# %%
import os

improvement_path = (
    "/content/drive/MyDrive/"
    "Food_Recognition_Project/improvement_data"
)

weak_classes = [
    "apple",
    "carrot",
    "donut",
    "hamburger",
    "peanut",
    "strawberry"
]

for class_name in weak_classes:
    os.makedirs(
        os.path.join(improvement_path, class_name),
        exist_ok=True
    )

print("Improvement folders created!")

for class_name in weak_classes:
    print(class_name)
# Out:
# Improvement folders created!
# apple
# carrot
# donut
# hamburger
# peanut
# strawberry

# %%
import os

improvement_path = (
    "/content/drive_new/MyDrive/"
    "Food_Recognition_Project/improvement_data"
)

weak_classes = [
    "apple",
    "carrot",
    "donut",
    "hamburger",
    "peanut",
    "strawberry"
]

valid_extensions = (
    ".jpg", ".jpeg", ".png",
    ".webp", ".jfif", ".avif"
)

total = 0

for class_name in weak_classes:
    folder = os.path.join(improvement_path, class_name)

    images = [
        f for f in os.listdir(folder)
        if f.lower().endswith(valid_extensions)
    ]

    print(class_name, ":", len(images))
    total += len(images)

print("\nTotal improvement images:", total)
# Out:
# apple : 10
# carrot : 10
# donut : 10
# hamburger : 10
# peanut : 10
# strawberry : 10
#
# Total improvement images: 60

# %% [markdown]
# 15.1 Add Improvement Images to Training Data
#
# This section adds the new diverse images from the weak food classes to the training dataset only. The validation and test datasets are kept unchanged so the model can still be evaluated fairly.

# %%
import os
from PIL import Image

improvement_path = (
    "/content/drive_new/MyDrive/"
    "Food_Recognition_Project/improvement_data"
)

train_path = (
    "/content/drive_new/MyDrive/"
    "Food_Recognition_Project/split_data/train"
)

weak_classes = [
    "apple",
    "carrot",
    "donut",
    "hamburger",
    "peanut",
    "strawberry"
]

added_total = 0

for class_name in weak_classes:

    source_folder = os.path.join(
        improvement_path,
        class_name
    )

    target_folder = os.path.join(
        train_path,
        class_name
    )

    os.makedirs(target_folder, exist_ok=True)

    files = os.listdir(source_folder)

    added_class = 0

    for i, filename in enumerate(files):

        source_file = os.path.join(
            source_folder,
            filename
        )

        try:
            # Open and convert to standard JPG
            image = Image.open(source_file).convert("RGB")

            new_filename = (
                f"improve_{class_name}_{i+1}.jpg"
            )

            target_file = os.path.join(
                target_folder,
                new_filename
            )

            image.save(
                target_file,
                "JPEG",
                quality=95
            )

            added_class += 1
            added_total += 1

        except Exception as e:
            print("Skipped:", filename, e)

    print(
        class_name,
        ":",
        added_class,
        "images added"
    )

print("\nTotal improvement images added:", added_total)
# Out:
# apple : 10 images added
# carrot : 10 images added
# donut : 10 images added
# hamburger : 10 images added
# peanut : 10 images added
# strawberry : 10 images added
#
# Total improvement images added: 60

# %% [markdown]
# Check the new training size

# %%
from torchvision import datasets

updated_train_dataset = datasets.ImageFolder(
    train_path
)

print(
    "Updated training images:",
    len(updated_train_dataset)
)
# Out:
# Updated training images: 2151

# %% [markdown]
# 15.2 Rebuild Training DataLoader
#
# This section reloads the updated training dataset after adding the new improvement images. A new DataLoader is created so the model can train using the additional images

# %%
from torchvision import transforms

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

print("train_transform ready!")
# Out:
# train_transform ready!

# %%
import os
from torchvision import datasets
from torch.utils.data import DataLoader

train_path = (
    "/content/drive_new/MyDrive/"
    "Food_Recognition_Project/split_data/train"
)

updated_train_dataset = datasets.ImageFolder(
    train_path,
    transform=train_transform
)

updated_train_loader = DataLoader(
    updated_train_dataset,
    batch_size=32,
    shuffle=True,
    num_workers=2
)

print("Updated training images:", len(updated_train_dataset))
print("Number of classes:", len(updated_train_dataset.classes))
print("Updated DataLoader ready!")
# Out:
# Updated training images: 2151
# Number of classes: 20
# Updated DataLoader ready!

# %% [markdown]
# 15.3 Load Final Model for Further Fine-Tuning
#
# This section loads the previous best fine-tuned MobileNetV2 model. The last three feature blocks are unfrozen again so the model can learn from the newly added diverse training images.

# %%
import torch
import torch.nn as nn
from torchvision import models

device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

# Create MobileNetV2 structure
model = models.mobilenet_v2(weights=None)

# Change classifier to 20 food classes
model.classifier[1] = nn.Linear(
    model.last_channel,
    20
)

# Load previous best model
model_path = (
    "/content/drive_new/MyDrive/"
    "Food_Recognition_Project/model/"
    "best_finetuned_mobilenetv2.pth"
)

model.load_state_dict(
    torch.load(model_path, map_location=device)
)

model = model.to(device)

# Freeze all feature layers
for param in model.features.parameters():
    param.requires_grad = False

# Unfreeze last 3 feature blocks
for layer in model.features[-3:]:
    for param in layer.parameters():
        param.requires_grad = True

print("Previous best fine-tuned model loaded!")
print("Device:", device)
print("Ready for improvement training!")
# Out:
# Previous best fine-tuned model loaded!
# Device: cuda
# Ready for improvement training!

# %% [markdown]
# Because Colab runtime restarted, create the validation transform and loader again.

# %%
from torchvision import transforms, datasets
from torch.utils.data import DataLoader

val_test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

validation_path = (
    "/content/drive_new/MyDrive/"
    "Food_Recognition_Project/split_data/validation"
)

validation_dataset = datasets.ImageFolder(
    validation_path,
    transform=val_test_transform
)

validation_loader = DataLoader(
    validation_dataset,
    batch_size=32,
    shuffle=False,
    num_workers=2
)

print("Validation images:", len(validation_dataset))
print("Validation DataLoader ready!")
# Out:
# Validation images: 596
# Validation DataLoader ready!

# %% [markdown]
# 15.4 Further Fine-Tuning with Improvement Data
#
# This section further fine-tunes the previous best MobileNetV2 model using the updated training dataset. The additional diverse images help the model learn difficult real-world food appearances. A small learning rate is used to avoid changing the pretrained knowledge too much.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import os

# Loss function
criterion = nn.CrossEntropyLoss()

# Smaller learning rate for further fine-tuning
optimizer = optim.Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=0.00005
)

improvement_epochs = 3

best_candidate_val_accuracy = 0.0

improve_train_accuracies = []
improve_val_accuracies = []

save_path = (
    "/content/drive_new/MyDrive/"
    "Food_Recognition_Project/model/"
    "best_improved_mobilenetv2.pth"
)

for epoch in range(improvement_epochs):

    # -------------------------
    # TRAINING
    # -------------------------
    model.train()

    train_correct = 0
    train_total = 0
    train_running_loss = 0.0

    for images, labels in updated_train_loader:

        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        train_running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)

        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_loss = (
        train_running_loss / len(updated_train_loader)
    )

    train_accuracy = (
        100 * train_correct / train_total
    )

    # -------------------------
    # VALIDATION
    # -------------------------
    model.eval()

    val_correct = 0
    val_total = 0
    val_running_loss = 0.0

    with torch.no_grad():

        for images, labels in validation_loader:

            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            val_running_loss += loss.item()

            _, predicted = torch.max(outputs, 1)

            val_total += labels.size(0)
            val_correct += (
                predicted == labels
            ).sum().item()

    val_loss = (
        val_running_loss / len(validation_loader)
    )

    val_accuracy = (
        100 * val_correct / val_total
    )

    improve_train_accuracies.append(train_accuracy)
    improve_val_accuracies.append(val_accuracy)

    print(f"Improvement Epoch {epoch+1}/{improvement_epochs}")

    print(
        f"Train Loss: {train_loss:.4f} | "
        f"Train Accuracy: {train_accuracy:.2f}%"
    )

    print(
        f"Validation Loss: {val_loss:.4f} | "
        f"Validation Accuracy: {val_accuracy:.2f}%"
    )

    # Save best candidate
    if val_accuracy > best_candidate_val_accuracy:

        best_candidate_val_accuracy = val_accuracy

        torch.save(
            model.state_dict(),
            save_path
        )

        print("✅ Best improvement model saved!")

    print("-" * 50)

print("\nImprovement training finished!")

print(
    f"Best Candidate Validation Accuracy: "
    f"{best_candidate_val_accuracy:.2f}%"
)

print("Previous Best Validation Accuracy: 91.61%")
# Out:
# Improvement Epoch 1/3
# Train Loss: 0.1359 | Train Accuracy: 96.65%
# Validation Loss: 0.2247 | Validation Accuracy: 92.28%
# ✅ Best improvement model saved!
# --------------------------------------------------
# Improvement Epoch 2/3
# Train Loss: 0.1209 | Train Accuracy: 96.84%
# Validation Loss: 0.2251 | Validation Accuracy: 92.28%
# --------------------------------------------------
# Improvement Epoch 3/3
# Train Loss: 0.1040 | Train Accuracy: 97.49%
# Validation Loss: 0.2118 | Validation Accuracy: 92.45%
# ✅ Best improvement model saved!
# --------------------------------------------------
#
# Improvement training finished!
# Best Candidate Validation Accuracy: 92.45%
# Previous Best Validation Accuracy: 91.61%

# %% [markdown]
# 15.5 Evaluate the Improved Model on the Test Dataset
#
# This section evaluates the improved MobileNetV2 model using the same unseen test dataset. The result is compared with the previous fine-tuned model to decide which model should be kept as the final model.

# %%
import torch
from torchvision import datasets
from torch.utils.data import DataLoader
from torchvision import transforms

# Test transform
val_test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# Test dataset path
test_path = (
    "/content/drive_new/MyDrive/"
    "Food_Recognition_Project/split_data/test"
)

test_dataset = datasets.ImageFolder(
    test_path,
    transform=val_test_transform
)

test_loader = DataLoader(
    test_dataset,
    batch_size=32,
    shuffle=False,
    num_workers=2
)

print("Test images:", len(test_dataset))
# Out:
# Test images: 311

# %%
import torch
import torch.nn as nn
from torchvision import models

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Create model structure
model = models.mobilenet_v2(weights=None)
model.classifier[1] = nn.Linear(model.last_channel, 20)

# Load improved model
improved_model_path = (
    "/content/drive_new/MyDrive/"
    "Food_Recognition_Project/model/"
    "best_improved_mobilenetv2.pth"
)

model.load_state_dict(
    torch.load(improved_model_path, map_location=device)
)

model = model.to(device)
model.eval()

criterion = nn.CrossEntropyLoss()

test_running_loss = 0.0
test_correct = 0
test_total = 0

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        loss = criterion(outputs, labels)
        test_running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)

        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

improved_test_loss = test_running_loss / len(test_loader)
improved_test_accuracy = 100 * test_correct / test_total

print(f"Improved Model Test Loss: {improved_test_loss:.4f}")
print(f"Improved Model Test Accuracy: {improved_test_accuracy:.2f}%")
print(f"Correct Predictions: {test_correct}/{test_total}")

print("\nComparison")
print("----------------------")
print("Previous Final Test Accuracy: 95.18%")
print(f"Improved Model Test Accuracy: {improved_test_accuracy:.2f}%")
# Out:
# Improved Model Test Loss: 0.1537
# Improved Model Test Accuracy: 95.50%
# Correct Predictions: 297/311
#
# Comparison
# ----------------------
# Previous Final Test Accuracy: 95.18%
# Improved Model Test Accuracy: 95.50%

# %% [markdown]
# Final Model Decision
#
# The improved MobileNetV2 model achieved 95.50% test accuracy, which is higher than the previous fine-tuned model accuracy of 95.18%. Therefore, best_improved_mobilenetv2.pth is selected as the final model.

# %% [markdown]
# 15.6 Real-World Test After Improvement
#
# This section tests the improved MobileNetV2 model on the same real-world demo images used before improvement. The results are compared to check whether the additional training images helped the model recognize difficult food classes better.

# %%
import os
import torch
import pandas as pd
from PIL import Image
from torchvision import transforms, models
import torch.nn as nn

# Paths
test_images_dir = (
    "/content/drive_new/MyDrive/"
    "Food_Recognition_Project/test_images"
)

model_path = (
    "/content/drive_new/MyDrive/"
    "Food_Recognition_Project/model/"
    "best_improved_mobilenetv2.pth"
)

nutrition_path = (
    "/content/drive_new/MyDrive/"
    "Food_Recognition_Project/nutrition/"
    "food_nutrition.csv"
)

# Classes
class_names = [
    'almond', 'apple', 'banana', 'broccoli', 'carrot',
    'cashew', 'chocolate_cake', 'cucumber', 'cupcake',
    'donut', 'french_fries', 'hamburger', 'hot_dog',
    'ice_cream', 'orange', 'peanut', 'pizza',
    'strawberry', 'tomato', 'walnut'
]

device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

# Create and load improved model
model = models.mobilenet_v2(weights=None)

model.classifier[1] = nn.Linear(
    model.last_channel,
    20
)

model.load_state_dict(
    torch.load(model_path, map_location=device)
)

model = model.to(device)
model.eval()

# Image preprocessing
prediction_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# Nutrition database
nutrition_df = pd.read_csv(nutrition_path)
nutrition_dict = nutrition_df.set_index("food").to_dict("index")

results = []

valid_extensions = (
    ".jpg", ".jpeg", ".png",
    ".webp", ".jfif"
)

for filename in sorted(os.listdir(test_images_dir)):

    if not filename.lower().endswith(valid_extensions):
        continue

    image_path = os.path.join(
        test_images_dir,
        filename
    )

    image = Image.open(image_path).convert("RGB")

    image_tensor = prediction_transform(image)
    image_tensor = image_tensor.unsqueeze(0).to(device)

    with torch.no_grad():

        output = model(image_tensor)

        probabilities = torch.softmax(
            output,
            dim=1
        )

        confidence, predicted_label = torch.max(
            probabilities,
            1
        )

    predicted_food = class_names[
        predicted_label.item()
    ]

    confidence_percent = confidence.item() * 100

    # Actual food from filename
    actual_food = os.path.splitext(filename)[0]
    actual_food = actual_food.replace("_test", "")

    # Confidence threshold
    if confidence_percent < 50:
        display_result = "Uncertain"
        category = "-"
        status = "Uncertain"

    else:
        display_result = predicted_food.replace(
            "_", " "
        ).title()

        category = nutrition_dict[
            predicted_food
        ]["category"]

        if predicted_food == actual_food:
            status = "Correct"
        else:
            status = "Wrong"

    results.append([
        filename,
        actual_food.replace("_", " ").title(),
        display_result,
        confidence_percent,
        category,
        status
    ])

# Create table
real_world_df = pd.DataFrame(
    results,
    columns=[
        "Image",
        "Actual Food",
        "Model Result",
        "Confidence (%)",
        "Category",
        "Correct?"
    ]
)

real_world_df["Confidence (%)"] = (
    real_world_df["Confidence (%)"].round(2)
)

display(real_world_df)

# Count results
correct_count = (
    real_world_df["Correct?"] == "Correct"
).sum()

uncertain_count = (
    real_world_df["Correct?"] == "Uncertain"
).sum()

wrong_count = (
    real_world_df["Correct?"] == "Wrong"
).sum()

total_count = len(real_world_df)

print("\nCorrect:", correct_count)
print("Uncertain:", uncertain_count)
print("Wrong:", wrong_count)
print("Total:", total_count)

print("\nPrevious Real-World Accuracy: 45.45%")
# Out:
#                   Image Actual Food Model Result  Confidence (%)   Category  \
# 0        apple_test.jpg       Apple        Apple           77.61      Fruit
# 1       banana_test.jpg      Banana       Banana           84.37      Fruit
# 2       carrot_test.jpg      Carrot       Carrot           50.92  Vegetable
# 3      cupcake_test.jpg     Cupcake      Cupcake           97.42    Dessert
# 4        donut_test.jpg       Donut        Donut           54.14    Dessert
# 5    hamburger_test.jpg   Hamburger    Hamburger           62.49  Fast Food
# 6      hot_dog_test.jpg     Hot Dog      Hot Dog           93.49  Fast Food
# 7    ice_cream_test.jpg   Ice Cream    Uncertain           38.39          -
# 8       peanut_test.jpg      Peanut       Peanut           66.17       Nuts
# 9        pizza_test.jpg       Pizza        Pizza           99.43  Fast Food
# 10  strawberry_test.jpg  Strawberry   Strawberry           98.58      Fruit
#
#      Correct?
# 0     Correct
# 1     Correct
# ...

# %% [markdown]
# 15.7 Update Final Result Files
#
# This section updates the final evaluation files using the improved MobileNetV2 model with 95.50% test accuracy.

# %%
test_path = (
    "/content/drive/MyDrive/"
    "Food_Recognition_Project/split_data/test"
)

print("Test folder exists:", os.path.exists(test_path))

if os.path.exists(test_path):
    print("Number of class folders:", len(os.listdir(test_path)))
# Out:
# Test folder exists: True
# Number of class folders: 20

# %%
import os
import torch
import torch.nn as nn
import pandas as pd
import matplotlib.pyplot as plt

from torchvision import models, transforms, datasets
from torch.utils.data import DataLoader
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# Paths
project_path = "/content/drive/MyDrive/Food_Recognition_Project"

model_path = os.path.join(
    project_path,
    "model",
    "best_improved_mobilenetv2.pth"
)

test_path = os.path.join(
    project_path,
    "split_data",
    "test"
)

results_dir = os.path.join(
    project_path,
    "results"
)

os.makedirs(results_dir, exist_ok=True)

# Device
device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

# Classes
class_names = [
    'almond', 'apple', 'banana', 'broccoli', 'carrot',
    'cashew', 'chocolate_cake', 'cucumber', 'cupcake',
    'donut', 'french_fries', 'hamburger', 'hot_dog',
    'ice_cream', 'orange', 'peanut', 'pizza',
    'strawberry', 'tomato', 'walnut'
]

# Image transform
prediction_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# Test dataset
test_dataset = datasets.ImageFolder(
    test_path,
    transform=prediction_transform
)

test_loader = DataLoader(
    test_dataset,
    batch_size=32,
    shuffle=False,
    num_workers=2
)

# Load improved model
model = models.mobilenet_v2(weights=None)

model.classifier[1] = nn.Linear(
    model.last_channel,
    20
)

model.load_state_dict(
    torch.load(model_path, map_location=device)
)

model = model.to(device)
model.eval()

# Predict test dataset
all_labels = []
all_predictions = []

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)

        outputs = model(images)

        _, predicted = torch.max(outputs, 1)

        all_labels.extend(labels.numpy())
        all_predictions.extend(
            predicted.cpu().numpy()
        )

# Final accuracy
correct = sum(
    p == y
    for p, y in zip(
        all_predictions,
        all_labels
    )
)

final_accuracy = (
    correct / len(all_labels) * 100
)

print("Final Test Images:", len(all_labels))
print("Correct Predictions:", correct)
print(f"Final Test Accuracy: {final_accuracy:.2f}%")
# Out:
# Final Test Images: 311
# Correct Predictions: 297
# Final Test Accuracy: 95.50%

# %%
# ==========================================
# Save final classification report
# ==========================================

report = classification_report(
    all_labels,
    all_predictions,
    target_names=class_names,
    digits=4,
    output_dict=True
)

report_df = pd.DataFrame(report).transpose()

report_df.to_csv(
    os.path.join(
        results_dir,
        "final_classification_report.csv"
    )
)

print("Final classification report updated!")


# ==========================================
# Save final confusion matrix
# ==========================================

cm = confusion_matrix(
    all_labels,
    all_predictions
)

fig, ax = plt.subplots(figsize=(14, 14))

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=class_names
)

disp.plot(
    ax=ax,
    xticks_rotation=90
)

plt.title("Final Improved MobileNetV2 Confusion Matrix")
plt.tight_layout()

plt.savefig(
    os.path.join(
        results_dir,
        "final_confusion_matrix.png"
    ),
    dpi=300,
    bbox_inches="tight"
)

plt.show()

print("Final confusion matrix updated!")


# ==========================================
# Update model comparison
# ==========================================

comparison_df = pd.DataFrame({
    "Model": [
        "Original MobileNetV2",
        "Fine-Tuned MobileNetV2",
        "Improved MobileNetV2"
    ],
    "Test Accuracy (%)": [
        92.28,
        95.18,
        95.50
    ]
})

comparison_df.to_csv(
    os.path.join(
        results_dir,
        "model_comparison.csv"
    ),
    index=False
)

display(comparison_df)

print("Model comparison updated!")
# Out:
# Final classification report updated!
# Final confusion matrix updated!
#                     Model  Test Accuracy (%)
# 0    Original MobileNetV2              92.28
# 1  Fine-Tuned MobileNetV2              95.18
# 2    Improved MobileNetV2              95.50
# Model comparison updated!

# %% [markdown]
# 15.8 Save Improved Real-World Results
#
# This section saves the improved model results from the real-world test images into a CSV file for documentation and comparison.

# %%
import os
import pandas as pd
from PIL import Image

test_images_dir = (
    "/content/drive/MyDrive/"
    "Food_Recognition_Project/test_images"
)

nutrition_path = (
    "/content/drive/MyDrive/"
    "Food_Recognition_Project/nutrition/"
    "food_nutrition.csv"
)

nutrition_df = pd.read_csv(nutrition_path)
nutrition_dict = nutrition_df.set_index("food").to_dict("index")

results = []

valid_extensions = (
    ".jpg", ".jpeg", ".png",
    ".webp", ".jfif"
)

for filename in sorted(os.listdir(test_images_dir)):

    if not filename.lower().endswith(valid_extensions):
        continue

    image_path = os.path.join(
        test_images_dir,
        filename
    )

    image = Image.open(image_path).convert("RGB")

    image_tensor = prediction_transform(
        image
    ).unsqueeze(0).to(device)

    with torch.no_grad():

        output = model(image_tensor)

        probabilities = torch.softmax(
            output,
            dim=1
        )

        confidence, predicted_label = torch.max(
            probabilities,
            1
        )

    predicted_food = class_names[
        predicted_label.item()
    ]

    confidence_percent = confidence.item() * 100

    actual_food = os.path.splitext(filename)[0]
    actual_food = actual_food.replace("_test", "")

    if confidence_percent < 50:

        model_result = "Uncertain"
        category = "-"
        status = "Uncertain"

    else:

        model_result = predicted_food.replace(
            "_", " "
        ).title()

        category = nutrition_dict[
            predicted_food
        ]["category"]

        if predicted_food == actual_food:
            status = "Correct"
        else:
            status = "Wrong"

    results.append([
        filename,
        actual_food.replace("_", " ").title(),
        model_result,
        round(confidence_percent, 2),
        category,
        status
    ])

real_world_df = pd.DataFrame(
    results,
    columns=[
        "Image",
        "Actual Food",
        "Model Result",
        "Confidence (%)",
        "Category",
        "Status"
    ]
)

display(real_world_df)

save_path = os.path.join(
    results_dir,
    "improved_real_world_results.csv"
)

real_world_df.to_csv(
    save_path,
    index=False
)

print("Improved real-world results saved!")
print(save_path)
# Out:
#                   Image Actual Food Model Result  Confidence (%)   Category  \
# 0        apple_test.jpg       Apple        Apple           77.61      Fruit
# 1       banana_test.jpg      Banana       Banana           84.37      Fruit
# 2       carrot_test.jpg      Carrot       Carrot           50.92  Vegetable
# 3      cupcake_test.jpg     Cupcake      Cupcake           97.42    Dessert
# 4        donut_test.jpg       Donut        Donut           54.14    Dessert
# 5    hamburger_test.jpg   Hamburger    Hamburger           62.49  Fast Food
# 6      hot_dog_test.jpg     Hot Dog      Hot Dog           93.49  Fast Food
# 7    ice_cream_test.jpg   Ice Cream    Uncertain           38.39          -
# 8       peanut_test.jpg      Peanut       Peanut           66.17       Nuts
# 9        pizza_test.jpg       Pizza        Pizza           99.43  Fast Food
# 10  strawberry_test.jpg  Strawberry   Strawberry           98.58      Fruit
#
#        Status
# 0     Correct
# 1     Correct
# ...

# %% [markdown]
# 16. Testing
#
# This section tests the final improved MobileNetV2 model using new food images.
# The user uploads food images and enters the estimated weight for each image.
# The system predicts the food class, confidence score, category, and estimated nutrition.
# If the confidence is below 50%, the system shows “Uncertain Prediction”.

# %%
import torch
import torch.nn as nn
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
from torchvision import models, transforms
from google.colab import files

# -------------------------
# Device
# -------------------------
device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

# -------------------------
# Classes
# -------------------------
class_names = [
    'almond', 'apple', 'banana', 'broccoli', 'carrot',
    'cashew', 'chocolate_cake', 'cucumber', 'cupcake',
    'donut', 'french_fries', 'hamburger', 'hot_dog',
    'ice_cream', 'orange', 'peanut', 'pizza',
    'strawberry', 'tomato', 'walnut'
]

# -------------------------
# Load final improved model
# -------------------------
model = models.mobilenet_v2(weights=None)

model.classifier[1] = nn.Linear(
    model.last_channel,
    20
)

model_path = (
    "/content/drive/MyDrive/"
    "Food_Recognition_Project/model/"
    "best_improved_mobilenetv2.pth"
)

model.load_state_dict(
    torch.load(model_path, map_location=device)
)

model = model.to(device)
model.eval()

# -------------------------
# Image preprocessing
# -------------------------
prediction_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# -------------------------
# Nutrition database
# -------------------------
nutrition_path = (
    "/content/drive/MyDrive/"
    "Food_Recognition_Project/nutrition/"
    "food_nutrition.csv"
)

nutrition_df = pd.read_csv(nutrition_path)
nutrition_dict = nutrition_df.set_index("food").to_dict("index")

print("✅ Final demo system ready!")
# Out:
# ✅ Final demo system ready!

# %%
# ==========================================
# FINAL FOOD IMAGE TESTING
# ==========================================

import os
import torch
import torch.nn as nn
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
from torchvision import models, transforms
from google.colab import files


# ==========================================
# 1. DEVICE
# ==========================================

device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

print("Using device:", device)


# ==========================================
# 2. FOOD CLASSES
# ==========================================

class_names = [
    'almond',
    'apple',
    'banana',
    'broccoli',
    'carrot',
    'cashew',
    'chocolate_cake',
    'cucumber',
    'cupcake',
    'donut',
    'french_fries',
    'hamburger',
    'hot_dog',
    'ice_cream',
    'orange',
    'peanut',
    'pizza',
    'strawberry',
    'tomato',
    'walnut'
]


# ==========================================
# 3. LOAD FINAL IMPROVED MODEL
# ==========================================

model_path = (
    "/content/drive/MyDrive/"
    "Food_Recognition_Project/model/"
    "best_improved_mobilenetv2.pth"
)

model = models.mobilenet_v2(weights=None)

model.classifier[1] = nn.Linear(
    model.last_channel,
    20
)

model.load_state_dict(
    torch.load(
        model_path,
        map_location=device
    )
)

model = model.to(device)
model.eval()

print("Final improved model loaded!")


# ==========================================
# 4. IMAGE PREPROCESSING
# ==========================================

prediction_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])


# ==========================================
# 5. LOAD NUTRITION DATABASE
# ==========================================

nutrition_path = (
    "/content/drive/MyDrive/"
    "Food_Recognition_Project/nutrition/"
    "food_nutrition.csv"
)

nutrition_df = pd.read_csv(
    nutrition_path
)

nutrition_dict = (
    nutrition_df
    .set_index("food")
    .to_dict("index")
)

print("Nutrition database loaded!")


# ==========================================
# 6. CHOOSE NUMBER OF IMAGES
# ==========================================

number_of_images = int(
    input("\nHow many food images do you want to test? ")
)

if number_of_images <= 0:
    raise ValueError(
        "Please enter a number greater than 0."
    )

print(
    f"\nPlease upload exactly "
    f"{number_of_images} food image(s)."
)


# ==========================================
# 7. UPLOAD IMAGES
# ==========================================

uploaded = files.upload()

uploaded_files = list(
    uploaded.keys()
)

# Check number of uploaded files
if len(uploaded_files) != number_of_images:

    print(
        f"\nYou selected {number_of_images} image(s), "
        f"but uploaded {len(uploaded_files)} file(s)."
    )

    print(
        "Please run this cell again and upload "
        "the correct number of images."
    )

    raise ValueError(
        "Number of uploaded images does not match."
    )

print("\nUploaded files:")

for filename in uploaded_files:
    print("-", filename)


# ==========================================
# 8. ENTER WEIGHT FOR EACH IMAGE
# ==========================================

weights = {}

print("\nEnter estimated weight for each food:")

for filename in uploaded_files:

    while True:

        try:

            portion = float(
                input(
                    f"Weight for {filename} (grams): "
                )
            )

            if portion <= 0:
                print(
                    "Weight must be greater than 0."
                )
                continue

            weights[filename] = portion
            break

        except ValueError:

            print(
                "Please enter a valid number."
            )

print("\nAll weights entered.")
print("Starting food prediction...")


# ==========================================
# 9. PREDICT ALL IMAGES
# ==========================================

demo_results = []

for filename in uploaded_files:

    portion_grams = weights[filename]

    # Open image
    original_image = Image.open(
        filename
    ).convert("RGB")

    # Prepare image
    image_tensor = prediction_transform(
        original_image
    )

    image_tensor = (
        image_tensor
        .unsqueeze(0)
        .to(device)
    )

    # Prediction
    with torch.no_grad():

        output = model(
            image_tensor
        )

        probabilities = torch.softmax(
            output,
            dim=1
        )

        confidence, predicted_label = torch.max(
            probabilities,
            1
        )

    predicted_food = class_names[
        predicted_label.item()
    ]

    confidence_percent = (
        confidence.item() * 100
    )


    # ======================================
    # LOW CONFIDENCE
    # ======================================

    if confidence_percent < 50:

        result_name = "Uncertain Prediction"
        category = "-"

        calories = "-"
        protein = "-"
        carbs = "-"
        fat = "-"


    # ======================================
    # CONFIDENT PREDICTION
    # ======================================

    else:

        result_name = (
            predicted_food
            .replace("_", " ")
            .title()
        )

        nutrition = nutrition_dict[
            predicted_food
        ]

        category = nutrition[
            "category"
        ]

        ratio = (
            portion_grams / 100
        )

        calories = round(
            nutrition["calories_kcal"]
            * ratio,
            2
        )

        protein = round(
            nutrition["protein_g"]
            * ratio,
            2
        )

        carbs = round(
            nutrition["carbs_g"]
            * ratio,
            2
        )

        fat = round(
            nutrition["fat_g"]
            * ratio,
            2
        )


    # Save result
    demo_results.append([
        filename,
        result_name,
        round(
            confidence_percent,
            2
        ),
        category,
        portion_grams,
        calories,
        protein,
        carbs,
        fat
    ])


# ==========================================
# 10. SHOW RESULTS ONE BY ONE
# ==========================================

print("\n")
print("=" * 50)
print("FOOD RECOGNITION RESULTS")
print("=" * 50)

for i, result in enumerate(
    demo_results
):

    filename = result[0]
    predicted_food = result[1]
    confidence = result[2]
    category = result[3]
    portion = result[4]
    calories = result[5]
    protein = result[6]
    carbs = result[7]
    fat = result[8]

    print("\n")
    print("=" * 50)
    print(
        f"RESULT {i + 1} "
        f"OF {len(demo_results)}"
    )
    print("=" * 50)

    print(
        "Image:",
        filename
    )

    # Uncertain
    if predicted_food == "Uncertain Prediction":

        print(
            "Result: Uncertain Prediction"
        )

        print(
            f"Confidence: {confidence}%"
        )

        print(
            "Category: -"
        )

        print("\nNutrition:")
        print(
            "Not shown because confidence "
            "is below 50%."
        )

    # Confident
    else:

        print(
            "Predicted Food:",
            predicted_food
        )

        print(
            f"Confidence: {confidence}%"
        )

        print(
            "Category:",
            category
        )

        print("\nEstimated Nutrition")
        print("-------------------------")

        print(
            f"Portion Size: {portion} g"
        )

        print(
            f"Calories: {calories} kcal"
        )

        print(
            f"Protein: {protein} g"
        )

        print(
            f"Carbohydrates: {carbs} g"
        )

        print(
            f"Fat: {fat} g"
        )


    # ======================================
    # SHOW IMAGE
    # ======================================

    original_image = Image.open(
        filename
    ).convert("RGB")

    plt.figure(
        figsize=(5, 5)
    )

    plt.imshow(
        original_image
    )

    if predicted_food == "Uncertain Prediction":

        plt.title(
            f"Uncertain Prediction\n"
            f"Confidence: {confidence}%"
        )

    else:

        plt.title(
            f"{predicted_food}\n"
            f"Confidence: {confidence}%"
        )

    plt.axis("off")
    plt.show()


# ==========================================
# 11. SAVE RESULTS TO GOOGLE DRIVE
# ==========================================

demo_df = pd.DataFrame(
    demo_results,
    columns=[
        "Image",
        "Predicted Food",
        "Confidence (%)",
        "Category",
        "Portion (g)",
        "Calories (kcal)",
        "Protein (g)",
        "Carbohydrates (g)",
        "Fat (g)"
    ]
)

results_dir = (
    "/content/drive/MyDrive/"
    "Food_Recognition_Project/results"
)

os.makedirs(
    results_dir,
    exist_ok=True
)

demo_result_path = os.path.join(
    results_dir,
    "final_live_demo_results.csv"
)

demo_df.to_csv(
    demo_result_path,
    index=False
)

print("\n" + "=" * 50)
print("TESTING COMPLETED!")
print("=" * 50)

print(
    "Total images tested:",
    len(demo_results)
)

print("\nResults saved to:")
print(
    demo_result_path
)
# Out:
# Using device: cpu
# Final improved model loaded!
# Nutrition database loaded!
#
# How many food images do you want to test? 5
#
# Please upload exactly 5 food image(s).
#      <input type="file" id="files-de96e7a6-5b40-428d-b889-fffa0a80c369" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de96e7a6-5b40-428d-b889-fffa0a80c369">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...
